# %%
import os
import pandas as pd
def merge_news_parts(out_dir="fmp_news_backfill", out_file="news_all.parquet"):
    parts_dir = os.path.join(out_dir, "parts")
    files = sorted([os.path.join(parts_dir, f) for f in os.listdir(parts_dir) if f.endswith(".parquet")])
    all_df = pd.concat((pd.read_parquet(f) for f in files), ignore_index=True)
    all_df.to_parquet(os.path.join(out_dir, out_file), index=False)
    return all_df

# %%
all_the_news = merge_news_parts()

# Dedupe on (url, symbol)
n_before = len(all_the_news)
all_the_news = all_the_news.drop_duplicates(subset=["url", "symbol"], keep="first")
print(f"Loaded {n_before:,} articles, {n_before - len(all_the_news):,} duplicates removed, {len(all_the_news):,} remaining")
# Out:
# Loaded 2,046,884 articles, 65,309 duplicates removed, 1,981,575 remaining

# %%
universe = pd.read_parquet('data/universe.pqt')
universe.head()
# Out:
#   symbol                                      Security Name
# 0   AACB  Artius II Acquisition Inc. - Class A Ordinary ...
# 1  AACBU                 Artius II Acquisition Inc. - Units
# 2   AACG  ATA Creativity Global - American Depositary Sh...
# 3    AAL       American Airlines Group, Inc. - Common Stock
# 4   AAME       Atlantic American Corporation - Common Stock

# %%
all_the_news.head()
# Out:
#   symbol        publishedDate      publisher  \
# 0   AACG  2020-12-18 07:00:00  GlobeNewsWire
# 1   AACG  2021-02-04 23:28:05       Benzinga
# 2   AACG  2021-02-04 14:17:34         Pulse2
# 3   AACG  2021-02-04 11:23:20  InvestorPlace
# 4   AACG  2021-04-13 16:05:00  GlobeNewsWire
#
#                                                title  \
# 0  ACG Announces Results of Annual General Meetin...
# 1          Why ATA Creativity Skyrocketed 951% Today
# 2  AACG Stock Price Increases Over 400%: Why It H...
# 3  AACG Stock: 7 Things to Know About ATA Creativ...
# 4  ATA Creativity Global Announces Filing of Annu...
#
#                                                image               site  \
# 0  https://images.financialmodelingprep.com/news/...  globenewswire.com
# 1  https://images.financialmodelingprep.com/news/...       benzinga.com
# 2  https://images.financialmodelingprep.com/news/...         pulse2.com
# 3  https://images.financialmodelingprep.com/news/...  investorplace.com
# 4  https://images.financialmodelingprep.com/news/...  globenewswire.com
#
#                                                 text  \
# 0  BEIJING, Dec. 18, 2020 (GLOBE NEWSWIRE) -- ATA...
# 1  ATA Creativity Global (NASDAQ: AACG) stock clo...
# 2  The stock price of ATA Creativity Global (NASD...
# 3  ATA Creativity (AACG) stock is rocketing highe...
# 4  BEIJING, China, April 13, 2021 (GLOBE NEWSWIRE...
#
#                                                  url window_from   window_to  \
# 0  https://www.globenewswire.com/news-release/202...  2020-12-18  2021-01-13
# 1  https://www.benzinga.com/news/21/02/19504724/w...  2021-01-13  2021-02-12
# 2  https://pulse2.com/aacg-stock-price-increases-...  2021-01-13  2021-02-12
# 3  https://investorplace.com/2021/02/aacg-stock-7...  2021-01-13  2021-02-12
# 4  https://www.globenewswire.com/news-release/202...  2021-03-14  2021-04-13
#
#    page
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
from anonymize_news import build_name_map, Anonymizer

# %%
name_map = build_name_map(universe)

# %%
from tqdm.auto import tqdm
from multiprocessing import Pool, cpu_count

# Global for worker processes
_anon = None

def _init_worker(name_map: dict[str, list[str]]):
    global _anon
    _anon = Anonymizer(name_map)

def _anon_row(args: tuple[str, str]) -> str:
    text, sym = args
    return _anon(text, sym)

def apply_anonymization(news_df: pd.DataFrame, name_map: dict[str, list[str]], n_workers: int | None = None) -> pd.DataFrame:
    df = news_df.copy()
    n_workers = n_workers or cpu_count()

    for col in ["title", "text"]:
        if col not in df.columns:
            continue
        pairs = list(zip(df[col].tolist(), df["symbol"].tolist()))
        
        with Pool(n_workers, initializer=_init_worker, initargs=(name_map,)) as pool:
            results = list(tqdm(
                pool.imap(_anon_row, pairs, chunksize=1000),
                total=len(pairs),
                desc=f"Anonymizing {col}"
            ))
        df[f"{col}_anon"] = results
    return df

# %%
ANON_OUTPUT_PATH = "data/all_the_news_anon.pqt"

# Check for existing anonymized data
try:
    existing_anon = pd.read_parquet(ANON_OUTPUT_PATH)
    already_done = set(zip(existing_anon["url"], existing_anon["symbol"]))
    print(f"Found {len(already_done):,} existing anonymized articles")
except FileNotFoundError:
    existing_anon = None
    already_done = set()
    print("No existing anonymized data found")

# Filter to only new articles
all_the_news["_key"] = list(zip(all_the_news["url"], all_the_news["symbol"]))
to_anon = all_the_news[~all_the_news["_key"].isin(already_done)].copy()
to_anon.drop(columns=["_key"], inplace=True)
all_the_news.drop(columns=["_key"], inplace=True)
print(f"{len(to_anon):,} articles to anonymize")
# Out:
# Found 1,748,717 existing anonymized articles
# 232,858 articles to anonymize

# %%
# Run anonymization on new articles only
if len(to_anon) == 0:
    print("Nothing new to anonymize")
    anon_df = existing_anon
else:
    new_anon_df = apply_anonymization(to_anon, name_map)
    
    # Append to existing or create new
    if existing_anon is not None:
        anon_df = pd.concat([existing_anon, new_anon_df], ignore_index=True)
    else:
        anon_df = new_anon_df
    
    anon_df.to_parquet(ANON_OUTPUT_PATH, index=False)
    print(f"Saved {len(anon_df):,} total anonymized articles")
# Out:
# Anonymizing title:   0%|          | 0/232858 [00:00<?, ?it/s]
# Anonymizing text:   0%|          | 0/232858 [00:00<?, ?it/s]

# %%
# Show duplicate URLs\n
url_counts = all_the_news["url"].value_counts()
dup_urls = url_counts[url_counts > 1]
print(f"{len(dup_urls):,} URLs appear more than once")
print(f"Top duplicates:\\n{dup_urls.head(10)}")

# Show example articles with same URL
example_url = dup_urls.index[0]
all_the_news[all_the_news["url"] == example_url][["symbol", "publishedDate", "title", "url"]]
# Out:
# 116,275 URLs appear more than once
# Top duplicates:\nurl
# https://www.gurufocus.com/news/3240667/first-look-fed-cut-looms-spacex-ipo-jj-myeloma-data-google-probe                        29
# https://www.investors.com/news/technology/biotech-stocks-the-top-5-to-watch-amid-a-blazing-hot-run/                            26
# https://www.gurufocus.com/news/3215323/market-today-tech-slide-meta-win-ai-deals-wbd-bids                                      26
# https://www.investors.com/etfs-and-funds/sectors/sp500-millennials-top-stock-is-up-195-percent-and-youve-never-heard-of-it/    24
# https://seekingalpha.com/article/4574414-restaurant-stocks-here-are-3-picks-for-2023                                           24
# https://www.gurufocus.com/news/3229645/first-look-versace-deal-crypto-slump-wbd-bids-and-airbus-woes                           24
# https://www.cnbc.com/2023/10/30/here-are-16-stocks-jim-cramer-is-watching-including-microsoft-chevron-southwest.html           24
# https://seekingalpha.com/article/4851378-top-50-high-quality-dividend-growth-stocks-for-december-2025                          22
# https://seekingalpha.com/article/4845053-baron-opportunity-fund-q3-2025-portfolio-update                                       22
# https://seekingalpha.com/article/4654898-why-i-made-big-changes-to-my-dividend-growth-portfolio                                22
# Name: count, dtype: int64
#         symbol        publishedDate  \
# 47531      ACI  2025-12-10 07:37:00
# 56361     ADBE  2025-12-10 07:37:00
# 98674      ALK  2025-12-10 07:37:00
# 184397    AVGO  2025-12-10 07:37:00
# 206568    BITF  2025-12-10 07:37:00
# 232672    CART  2025-12-10 07:37:00
# 259724    CLSK  2025-12-10 07:37:00
# 276467    CORZ  2025-12-10 07:37:00
# 280715    COST  2025-12-10 07:37:00
# 525535    IREN  2025-12-10 07:37:00
# 561024    LEGN  2025-12-10 07:37:00
# 566522     LIN  2025-12-10 07:37:00
# 583625    LULU  2025-12-10 07:37:00
# 590656    MARA  2025-12-10 07:37:00
# 620363    META  2025-12-10 07:37:00
# 661921    MSFT  2025-12-10 07:37:00
# 690486    NFLX  2025-12-10 07:37:00
# 732260    NVDA  2025-12-10 07:37:00
# 737812    NXPI  2025-12-10 07:37:00
# 834310    RIOT  2025-12-10 07:37:00
# 839530    RJET  2025-12-10 07:37:00
# 842075    RKLB  2025-12-10 07:37:00
# 859982    SATS  2025-12-10 07:37:00
# 874880     SFM  2025-12-10 07:37:00
# 896523    SNPS  2025-12-10 07:37:00
# 925633     SYM  2025-12-10 07:37:00
# 982503    TSLA  2025-12-10 07:37:00
# 1029932    WBD  2025-12-10 07:37:00
# 1050677   WULF  2025-12-10 07:37:00
#
#                                                      title  \
# 47531    First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 56361    First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 98674    First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 184397   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 206568   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 232672   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 259724   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 276467   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 280715   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 525535   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 561024   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 566522   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 583625   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 590656   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 620363   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 661921   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 690486   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 732260   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 737812   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 834310   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 839530   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 842075   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 859982   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 874880   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 896523   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 925633   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 982503   First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 1029932  First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
# 1050677  First Look: Fed Cut Looms; SpaceX IPO; J&J Mye...
#
#                                                        url
# 47531    https://www.gurufocus.com/news/3240667/first-l...
# 56361    https://www.gurufocus.com/news/3240667/first-l...
# 98674    https://www.gurufocus.com/news/3240667/first-l...
# 184397   https://www.gurufocus.com/news/3240667/first-l...
# 206568   https://www.gurufocus.com/news/3240667/first-l...
# 232672   https://www.gurufocus.com/news/3240667/first-l...
# 259724   https://www.gurufocus.com/news/3240667/first-l...
# 276467   https://www.gurufocus.com/news/3240667/first-l...
# 280715   https://www.gurufocus.com/news/3240667/first-l...
# 525535   https://www.gurufocus.com/news/3240667/first-l...
# 561024   https://www.gurufocus.com/news/3240667/first-l...
# 566522   https://www.gurufocus.com/news/3240667/first-l...
# 583625   https://www.gurufocus.com/news/3240667/first-l...
# 590656   https://www.gurufocus.com/news/3240667/first-l...
# 620363   https://www.gurufocus.com/news/3240667/first-l...
# 661921   https://www.gurufocus.com/news/3240667/first-l...
# 690486   https://www.gurufocus.com/news/3240667/first-l...
# 732260   https://www.gurufocus.com/news/3240667/first-l...
# 737812   https://www.gurufocus.com/news/3240667/first-l...
# 834310   https://www.gurufocus.com/news/3240667/first-l...
# 839530   https://www.gurufocus.com/news/3240667/first-l...
# 842075   https://www.gurufocus.com/news/3240667/first-l...
# 859982   https://www.gurufocus.com/news/3240667/first-l...
# 874880   https://www.gurufocus.com/news/3240667/first-l...
# 896523   https://www.gurufocus.com/news/3240667/first-l...
# 925633   https://www.gurufocus.com/news/3240667/first-l...
# 982503   https://www.gurufocus.com/news/3240667/first-l...
# 1029932  https://www.gurufocus.com/news/3240667/first-l...
# 1050677  https://www.gurufocus.com/news/3240667/first-l...
