# %% [markdown]
# # 4.0 Backtrader Backtest
#
# Run and analyze the short strategy using backtrader for more realistic simulation.

# %%
import sys
sys.path.insert(0, '.')

import logging
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

logging.basicConfig(level=logging.INFO, format='%(levelname)s - %(message)s')

plt.style.use('seaborn-v0_8-whitegrid')
plt.rcParams['figure.figsize'] = (14, 6)

# %% [markdown]
# ## 1. Run Backtest

# %%
from trading.bt_runner import run_backtest
from trading.config import DEFAULT_CONFIG

# Configuration
MODEL_PATH = Path('data/model_final.pt')
DATA_DIR = Path('data')

# Date range - TEST SET (model was trained on data before 2024-10-22)
# Train: 2021-01-13 to 2024-05-01
# Val:   2024-05-02 to 2024-10-21
# Test:  2024-10-22 to 2025-12-18
START_DATE = '2024-10-22'
END_DATE = '2025-12-18'

# Options
INITIAL_CASH = 100_000
MAX_SYMBOLS = None  # None = all symbols (slow), set to 500-1000 for faster testing
USE_DD_SCALING = True
USE_CONFIDENCE = False

# %%
# %%time

result = run_backtest(
    model_path=MODEL_PATH,
    data_dir=DATA_DIR,
    start_date=START_DATE,
    end_date=END_DATE,
    initial_cash=INITIAL_CASH,
    use_dd_scaling=USE_DD_SCALING,
    use_confidence=USE_CONFIDENCE,
    max_symbols=MAX_SYMBOLS,
)
# Out:
# INFO - Starting backtest
# INFO -   Model: data/model_final.pt
# INFO -   Data: data
# INFO -   Period: 2024-10-22 to 2025-12-18
# INFO - Loaded model from data/model_final.pt
# INFO -   Price features: 9
# INFO -   Fund features: 19
# INFO -   Embedding dims: 768
# INFO - Loading price data from data/prices.pqt...
# INFO -   Loaded 5,888,410 rows
# INFO -   Splitting into per-symbol DataFrames...
# INFO -     Processed 1,000/5,644 symbols...
# INFO -     Processed 2,000/5,644 symbols...
# INFO -     Processed 3,000/5,644 symbols...
# INFO -     Processed 4,000/5,644 symbols...
# INFO -     Processed 5,000/5,644 symbols...
# INFO -   Done: 5,644 symbols loaded
# INFO - Adding data feeds to cerebro...
# INFO -   Processed 1,000/5,644 symbols (843 added)...
# INFO -   Processed 2,000/5,644 symbols (1,690 added)...
# INFO -   Processed 3,000/5,644 symbols (2,531 added)...
# INFO -   Processed 4,000/5,644 symbols (3,449 added)...
# INFO -   Processed 5,000/5,644 symbols (4,417 added)...
# INFO -   Done: 5,028 data feeds added (616 skipped)
# INFO - Loading features from data/ml_dataset.pqt...
# INFO -   Loaded 2,092,929 rows, 804 columns
# INFO -   Filtered to 464,188 rows for 2,765 symbols
# INFO - Prepared 458094 feature rows for backtest
# INFO - Running backtest: 238 trading days, 5,028 symbols...
# INFO -   Initial cash: $100,000
# INFO - Strategy initialized with 5,028 symbols
# INFO - Progress: 2025-11-17 | Value: $100,000 (+0.0%)
# INFO - 2025-11-17 - Rebalancing: DD=0.0%, scale=1.00, targets=5
# INFO - 2025-11-17 - SHORT: CMND 1805 shares @ ~11.08
# INFO - 2025-11-17 - SHORT: MOVE 1970 shares @ ~10.15
# INFO - 2025-11-17 - SHORT: AVDL 868 shares @ ~23.02
# INFO - 2025-11-17 - SHORT: GLTO 875 shares @ ~22.85
# INFO - 2025-11-17 - SHORT: PZZA 497 shares @ ~40.22
# INFO - 2025-11-18 - SELL EXECUTED: CMND @ 14.08
# INFO - 2025-11-18 - SELL EXECUTED: MOVE @ 10.22
# INFO - 2025-11-18 - SELL EXECUTED: AVDL @ 23.07
# INFO - 2025-11-18 - SELL EXECUTED: GLTO @ 21.94
# INFO - 2025-11-18 - SELL EXECUTED: PZZA @ 39.88
# INFO - 2025-11-18 - Rebalancing: DD=0.0%, scale=1.00, targets=5
# INFO - 2025-11-18 - CLOSING: AVDL (not in bottom-K)
# INFO - 2025-11-18 - CLOSING: MOVE (not in bottom-K)
# INFO - 2025-11-18 - CLOSING: PZZA (not in bottom-K)
# INFO - 2025-11-18 - SHORT: WKHS 2372 shares @ ~9.10
# INFO - 2025-11-18 - SHORT: CMND 688 shares @ ~8.66
# INFO - 2025-11-18 - SHORT: ALGT 338 shares @ ~63.70
# INFO - 2025-11-18 - SHORT: ENGN 3138 shares @ ~6.88
# INFO - 2025-11-18 - SHORT: GLTO 159 shares @ ~20.87
# INFO - 2025-11-19 - BUY EXECUTED: AVDL @ 23.04
# INFO - 2025-11-19 - BUY EXECUTED: MOVE @ 10.69
# INFO - 2025-11-19 - BUY EXECUTED: PZZA @ 41.16
# INFO - 2025-11-19 - SELL EXECUTED: WKHS @ 8.83
# INFO - 2025-11-19 - SELL EXECUTED: CMND @ 8.40
# INFO - 2025-11-19 - SELL EXECUTED: ALGT @ 64.25
# INFO - 2025-11-19 - SELL EXECUTED: ENGN @ 6.98
# INFO - 2025-11-19 - SELL EXECUTED: GLTO @ 19.84
# INFO - 2025-11-19 - TRADE CLOSED: AVDL PnL=26.04 (-174.08 net)
# INFO - 2025-11-19 - TRADE CLOSED: MOVE PnL=-925.90 (-1131.86 net)
# INFO - 2025-11-19 - TRADE CLOSED: PZZA PnL=-636.16 (-837.54 net)
# INFO - 2025-11-19 - Rebalancing: DD=0.0%, scale=1.00, targets=5
# INFO - 2025-11-19 - CLOSING: ALGT (not in bottom-K)
# INFO - 2025-11-19 - CLOSING: CMND (not in bottom-K)
# INFO - 2025-11-19 - CLOSING: ENGN (not in bottom-K)
# INFO - 2025-11-19 - CLOSING: GLTO (not in bottom-K)
# INFO - 2025-11-19 - CLOSING: WKHS (not in bottom-K)
# INFO - 2025-11-19 - SHORT: UNIT 3734 shares @ ~5.96
# INFO - 2025-11-19 - SHORT: ASTS 383 shares @ ~58.01
# INFO - 2025-11-19 - SHORT: OLMA 1145 shares @ ~19.43
# INFO - 2025-11-19 - SHORT: PSNL 2701 shares @ ~8.24
# INFO - 2025-11-19 - SHORT: RXO 2030 shares @ ~10.96
# INFO - 2025-11-20 - BUY EXECUTED: ALGT @ 63.39
# INFO - 2025-11-20 - BUY EXECUTED: CMND @ 8.03
# INFO - 2025-11-20 - BUY EXECUTED: ENGN @ 6.85
# INFO - 2025-11-20 - BUY EXECUTED: GLTO @ 19.30
# INFO - 2025-11-20 - BUY EXECUTED: WKHS @ 8.64
# INFO - 2025-11-20 - SELL EXECUTED: UNIT @ 6.07
# INFO - 2025-11-20 - SELL EXECUTED: ASTS @ 61.38
# INFO - 2025-11-20 - SELL EXECUTED: OLMA @ 20.52
# INFO - 2025-11-20 - SELL EXECUTED: PSNL @ 8.35
# INFO - 2025-11-20 - SELL EXECUTED: RXO @ 11.18
# INFO - 2025-11-20 - TRADE CLOSED: ALGT PnL=290.68 (74.97 net)
# INFO - 2025-11-20 - TRADE CLOSED: CMND PnL=11174.81 (10918.75 net)
# INFO - 2025-11-20 - TRADE CLOSED: ENGN PnL=407.94 (190.95 net)
# INFO - 2025-11-20 - TRADE CLOSED: GLTO PnL=2395.86 (2184.32 net)
# INFO - 2025-11-20 - TRADE CLOSED: WKHS PnL=450.68 (243.49 net)
# INFO - 2025-11-21 - STOP LOSS: PSNL entry=8.35 current=9.73 loss=16.5%
# INFO - 2025-11-24 - BUY EXECUTED: PSNL @ 9.78
# INFO - 2025-11-24 - TRADE CLOSED: PSNL PnL=-3862.43 (-4107.28 net)
# INFO - 2025-11-24 - STOP LOSS: OLMA entry=20.52 current=25.05 loss=22.1%
# INFO - 2025-11-25 - BUY EXECUTED: OLMA @ 25.05
# INFO - 2025-11-25 - TRADE CLOSED: OLMA PnL=-5186.85 (-5447.74 net)
# INFO - 2025-11-25 - STOP LOSS: RXO entry=11.18 current=13.00 loss=16.3%
# INFO - 2025-11-26 - BUY EXECUTED: RXO @ 12.89
# INFO - 2025-11-26 - TRADE CLOSED: RXO PnL=-3471.30 (-3715.61 net)
# INFO - 2025-11-28 - Rebalancing: DD=11.2%, scale=0.91, targets=5
# INFO - 2025-11-28 - CLOSING: ASTS (not in bottom-K)
# INFO - 2025-11-28 - CLOSING: UNIT (not in bottom-K)
# INFO - 2025-11-28 - SHORT: NNE 550 shares @ ~32.70
# INFO - 2025-11-28 - SHORT: PLAY 1028 shares @ ~17.49
# INFO - 2025-11-28 - SHORT: RXO 1360 shares @ ~13.22
# INFO - 2025-11-28 - SHORT: RKLB 426 shares @ ~42.14
# INFO - 2025-11-28 - SHORT: CMND 2910 shares @ ~6.18
# INFO - 2025-12-01 - BUY EXECUTED: ASTS @ 54.35
# INFO - 2025-12-01 - BUY EXECUTED: UNIT @ 6.27
# INFO - 2025-12-01 - SELL EXECUTED: NNE @ 31.75
# INFO - 2025-12-01 - SELL EXECUTED: PLAY @ 17.24
# INFO - 2025-12-01 - SELL EXECUTED: RXO @ 12.97
# INFO - 2025-12-01 - SELL EXECUTED: RKLB @ 41.15
# INFO - 2025-12-01 - SELL EXECUTED: CMND @ 6.20
# INFO - 2025-12-01 - TRADE CLOSED: ASTS PnL=2692.49 (2470.87 net)
# INFO - 2025-12-01 - TRADE CLOSED: UNIT PnL=-746.80 (-977.19 net)
# INFO - Progress: 2025-12-01 | Value: $100,305 (+0.3%)
# INFO - 2025-12-03 - Rebalancing: DD=10.5%, scale=0.96, targets=5
# INFO - 2025-12-03 - CLOSING: CMND (not in bottom-K)
# INFO - 2025-12-03 - CLOSING: NNE (not in bottom-K)
# INFO - 2025-12-03 - CLOSING: PLAY (not in bottom-K)
# INFO - 2025-12-03 - CLOSING: RKLB (not in bottom-K)
# INFO - 2025-12-03 - CLOSING: RXO (not in bottom-K)
# INFO - 2025-12-03 - SHORT: TGL 3199 shares @ ~5.99
# INFO - 2025-12-03 - SHORT: ETHZ 1691 shares @ ~11.33
# INFO - 2025-12-03 - SHORT: APLD 652 shares @ ~29.36
# INFO - 2025-12-03 - SHORT: SYM 261 shares @ ~73.22
# INFO - 2025-12-03 - SHORT: SMX 327 shares @ ~58.49
# INFO - 2025-12-04 - BUY EXECUTED: CMND @ 4.68
# INFO - 2025-12-04 - BUY EXECUTED: NNE @ 33.71
# INFO - 2025-12-04 - BUY EXECUTED: PLAY @ 17.56
# INFO - 2025-12-04 - BUY EXECUTED: RKLB @ 45.65
# INFO - 2025-12-04 - BUY EXECUTED: RXO @ 14.17
# INFO - 2025-12-04 - SELL EXECUTED: TGL @ 5.71
# INFO - 2025-12-04 - SELL EXECUTED: ETHZ @ 11.25
# INFO - 2025-12-04 - SELL EXECUTED: APLD @ 29.18
# INFO - 2025-12-04 - SELL EXECUTED: SYM @ 62.21
# INFO - 2025-12-04 - SELL EXECUTED: SMX @ 62.60
# INFO - 2025-12-04 - TRADE CLOSED: CMND PnL=4423.20 (4264.90 net)
# INFO - 2025-12-04 - TRADE CLOSED: NNE PnL=-1078.00 (-1258.02 net)
# INFO - 2025-12-04 - TRADE CLOSED: PLAY PnL=-328.96 (-507.83 net)
# INFO - 2025-12-04 - TRADE CLOSED: RKLB PnL=-1917.00 (-2101.88 net)
# INFO - 2025-12-04 - TRADE CLOSED: RXO PnL=-1632.00 (-1816.55 net)
# INFO - 2025-12-04 - STOP LOSS: SMX entry=62.60 current=141.00 loss=125.2%
# INFO - 2025-12-04 - STOP LOSS: TGL entry=5.71 current=6.76 loss=18.4%
# INFO - 2025-12-04 - Rebalancing: DD=39.7%, scale=0.25, targets=5
# INFO - 2025-12-04 - CLOSING: APLD (not in bottom-K)
# INFO - 2025-12-04 - CLOSING: ETHZ (not in bottom-K)
# INFO - 2025-12-04 - CLOSING: SMX (not in bottom-K)
# INFO - 2025-12-04 - CLOSING: SYM (not in bottom-K)
# INFO - 2025-12-04 - CLOSING: TGL (not in bottom-K)
# INFO - 2025-12-04 - SHORT: PLRZ 231 shares @ ~14.50
# INFO - 2025-12-04 - SHORT: TMC 429 shares @ ~7.80
# INFO - 2025-12-04 - SHORT: FWDI 389 shares @ ~8.61
# INFO - 2025-12-04 - SHORT: AEVA 211 shares @ ~15.88
# INFO - 2025-12-04 - SHORT: BA 16 shares @ ~201.87
# INFO - 2025-12-05 - Order TGL failed: 7
# INFO - 2025-12-05 - BUY EXECUTED: SMX @ 266.01
# INFO - 2025-12-05 - BUY EXECUTED: TGL @ 6.82
# INFO - 2025-12-05 - BUY EXECUTED: APLD @ 31.84
# INFO - 2025-12-05 - BUY EXECUTED: ETHZ @ 11.70
# INFO - 2025-12-05 - Order SMX failed: 7
# INFO - 2025-12-05 - BUY EXECUTED: SYM @ 59.73
# INFO - 2025-12-05 - SELL EXECUTED: PLRZ @ 12.57
# INFO - 2025-12-05 - SELL EXECUTED: TMC @ 7.74
# INFO - 2025-12-05 - SELL EXECUTED: FWDI @ 8.55
# INFO - 2025-12-05 - SELL EXECUTED: AEVA @ 15.51
# INFO - 2025-12-05 - SELL EXECUTED: BA @ 201.40
# INFO - 2025-12-05 - TRADE CLOSED: SMX PnL=-66515.07 (-67052.35 net)
# INFO - 2025-12-05 - TRADE CLOSED: TGL PnL=-3550.89 (-3751.31 net)
# INFO - 2025-12-05 - TRADE CLOSED: APLD PnL=-1734.32 (-1933.25 net)
# INFO - 2025-12-05 - TRADE CLOSED: ETHZ PnL=-760.95 (-954.99 net)
# INFO - 2025-12-05 - TRADE CLOSED: SYM PnL=647.28 (488.15 net)
# INFO - 2025-12-05 - Rebalancing: DD=77.3%, scale=0.25, targets=5
# INFO - 2025-12-05 - CLOSING: AEVA (not in bottom-K)
# INFO - 2025-12-05 - CLOSING: FWDI (not in bottom-K)
# INFO - 2025-12-05 - CLOSING: PLRZ (not in bottom-K)
# INFO - 2025-12-05 - CLOSING: TMC (not in bottom-K)
# INFO - 2025-12-05 - CLOSING: BA (not in bottom-K)
# INFO - 2025-12-05 - SHORT: TGL 49 shares @ ~25.44
# INFO - 2025-12-05 - SHORT: NB 193 shares @ ~6.51
# INFO - 2025-12-05 - SHORT: SMX 3 shares @ ~331.98
# INFO - 2025-12-05 - SHORT: CMND 244 shares @ ~5.16
# INFO - 2025-12-05 - SHORT: ALGT 15 shares @ ~82.64
# INFO - 2025-12-08 - BUY EXECUTED: AEVA @ 15.20
# INFO - 2025-12-08 - BUY EXECUTED: FWDI @ 8.42
# INFO - 2025-12-08 - BUY EXECUTED: PLRZ @ 11.50
# INFO - 2025-12-08 - BUY EXECUTED: TMC @ 7.61
# INFO - 2025-12-08 - BUY EXECUTED: BA @ 203.61
# INFO - 2025-12-08 - SELL EXECUTED: TGL @ 51.23
# INFO - 2025-12-08 - SELL EXECUTED: NB @ 6.78
# INFO - 2025-12-08 - SELL EXECUTED: SMX @ 220.00
# INFO - 2025-12-08 - SELL EXECUTED: CMND @ 4.97
# INFO - 2025-12-08 - SELL EXECUTED: ALGT @ 82.34
# INFO - 2025-12-08 - TRADE CLOSED: AEVA PnL=65.41 (33.01 net)
# INFO - 2025-12-08 - TRADE CLOSED: FWDI PnL=50.57 (17.56 net)
# INFO - 2025-12-08 - TRADE CLOSED: PLRZ PnL=247.17 (219.37 net)
# INFO - 2025-12-08 - TRADE CLOSED: TMC PnL=55.77 (22.84 net)
# INFO - 2025-12-08 - TRADE CLOSED: BA PnL=-35.36 (-67.76 net)
# INFO - 2025-12-11 - Rebalancing: DD=75.0%, scale=0.25, targets=5
# INFO - 2025-12-11 - CLOSING: ALGT (not in bottom-K)
# INFO - 2025-12-11 - CLOSING: CMND (not in bottom-K)
# INFO - 2025-12-11 - CLOSING: NB (not in bottom-K)
# INFO - 2025-12-11 - CLOSING: TGL (not in bottom-K)
# INFO - 2025-12-11 - SHORT: PLRZ 112 shares @ ~12.41
# INFO - 2025-12-11 - SHORT: FLNC 53 shares @ ~25.79
# INFO - 2025-12-11 - SHORT: WBTN 107 shares @ ~12.95
# INFO - 2025-12-11 - SHORT: DYN 71 shares @ ~19.42
# INFO - 2025-12-11 - SHORT: SMX 3 shares @ ~213.07
# INFO - 2025-12-12 - BUY EXECUTED: ALGT @ 88.12
# INFO - 2025-12-12 - BUY EXECUTED: CMND @ 3.16
# INFO - 2025-12-12 - BUY EXECUTED: NB @ 6.47
# INFO - 2025-12-12 - BUY EXECUTED: TGL @ 9.91
# INFO - 2025-12-12 - SELL EXECUTED: PLRZ @ 12.45
# INFO - 2025-12-12 - SELL EXECUTED: FLNC @ 25.44
# INFO - 2025-12-12 - SELL EXECUTED: WBTN @ 12.99
# INFO - 2025-12-12 - SELL EXECUTED: DYN @ 19.51
# INFO - 2025-12-12 - SELL EXECUTED: SMX @ 231.00
# INFO - 2025-12-12 - TRADE CLOSED: ALGT PnL=-86.70 (-99.48 net)
# INFO - 2025-12-12 - TRADE CLOSED: CMND PnL=441.64 (431.72 net)
# INFO - 2025-12-12 - TRADE CLOSED: NB PnL=59.83 (47.04 net)
# INFO - 2025-12-12 - TRADE CLOSED: TGL PnL=2024.68 (2009.70 net)
# INFO - 2025-12-12 - Rebalancing: DD=74.7%, scale=0.25, targets=5
# INFO - 2025-12-12 - CLOSING: DYN (not in bottom-K)
# INFO - 2025-12-12 - CLOSING: FLNC (not in bottom-K)
# INFO - 2025-12-12 - CLOSING: PLRZ (not in bottom-K)
# INFO - 2025-12-12 - CLOSING: SMX (not in bottom-K)
# INFO - 2025-12-12 - CLOSING: WBTN (not in bottom-K)
# INFO - 2025-12-12 - SHORT: ALGT 16 shares @ ~85.86
# INFO - 2025-12-12 - SHORT: TGL 163 shares @ ~8.59
# INFO - 2025-12-12 - SHORT: WVE 84 shares @ ~16.56
# INFO - 2025-12-12 - SHORT: FULC 108 shares @ ~13.00
# INFO - 2025-12-12 - SHORT: APLD 50 shares @ ~27.86
# INFO - 2025-12-15 - BUY EXECUTED: DYN @ 19.31
# INFO - 2025-12-15 - BUY EXECUTED: FLNC @ 22.61
# INFO - 2025-12-15 - BUY EXECUTED: PLRZ @ 11.89
# INFO - 2025-12-15 - BUY EXECUTED: SMX @ 169.90
# INFO - 2025-12-15 - BUY EXECUTED: WBTN @ 12.57
# INFO - 2025-12-15 - SELL EXECUTED: ALGT @ 87.96
# INFO - 2025-12-15 - SELL EXECUTED: TGL @ 8.29
# INFO - 2025-12-15 - SELL EXECUTED: WVE @ 16.75
# INFO - 2025-12-15 - SELL EXECUTED: FULC @ 12.92
# INFO - 2025-12-15 - SELL EXECUTED: APLD @ 27.86
# INFO - 2025-12-15 - TRADE CLOSED: DYN PnL=14.20 (0.42 net)
# INFO - 2025-12-15 - TRADE CLOSED: FLNC PnL=149.99 (137.26 net)
# INFO - 2025-12-15 - TRADE CLOSED: PLRZ PnL=62.72 (49.09 net)
# INFO - 2025-12-15 - TRADE CLOSED: SMX PnL=333.60 (321.74 net)
# INFO - 2025-12-15 - TRADE CLOSED: WBTN PnL=44.94 (31.27 net)
# INFO - 2025-12-15 - Rebalancing: DD=74.1%, scale=0.25, targets=5
# INFO - 2025-12-15 - CLOSING: ALGT (not in bottom-K)
# INFO - 2025-12-15 - CLOSING: APLD (not in bottom-K)
# INFO - 2025-12-15 - CLOSING: FULC (not in bottom-K)
# INFO - 2025-12-15 - CLOSING: TGL (not in bottom-K)
# INFO - 2025-12-15 - SHORT: WVE 5 shares @ ~16.11
# INFO - 2025-12-15 - SHORT: ZBIO 44 shares @ ~32.59
# INFO - 2025-12-15 - SHORT: TLRY 132 shares @ ~10.93
# INFO - 2025-12-15 - SHORT: OPCH 43 shares @ ~33.54
# INFO - 2025-12-15 - SHORT: CLSK 121 shares @ ~11.92
# INFO - 2025-12-16 - BUY EXECUTED: ALGT @ 87.33
# INFO - 2025-12-16 - BUY EXECUTED: APLD @ 23.36
# INFO - 2025-12-16 - BUY EXECUTED: FULC @ 12.73
# INFO - 2025-12-16 - BUY EXECUTED: TGL @ 5.87
# INFO - 2025-12-16 - SELL EXECUTED: WVE @ 16.80
# INFO - 2025-12-16 - SELL EXECUTED: ZBIO @ 32.09
# INFO - 2025-12-16 - SELL EXECUTED: TLRY @ 10.51
# INFO - 2025-12-16 - SELL EXECUTED: OPCH @ 33.52
# INFO - 2025-12-16 - SELL EXECUTED: CLSK @ 11.95
# INFO - 2025-12-16 - TRADE CLOSED: ALGT PnL=10.08 (-3.94 net)
# INFO - 2025-12-16 - TRADE CLOSED: APLD PnL=225.00 (212.19 net)
# INFO - 2025-12-16 - TRADE CLOSED: FULC PnL=20.52 (6.67 net)
# INFO - 2025-12-16 - TRADE CLOSED: TGL PnL=394.46 (382.92 net)
# INFO - 2025-12-16 - STOP LOSS: TLRY entry=10.51 current=13.94 loss=32.6%
# INFO - 2025-12-16 - Rebalancing: DD=74.7%, scale=0.25, targets=5
# INFO - 2025-12-16 - CLOSING: CLSK (not in bottom-K)
# INFO - 2025-12-16 - CLOSING: OPCH (not in bottom-K)
# INFO - 2025-12-16 - CLOSING: TLRY (not in bottom-K)
# INFO - 2025-12-16 - CLOSING: WVE (not in bottom-K)
# INFO - 2025-12-16 - CLOSING: ZBIO (not in bottom-K)
# INFO - 2025-12-16 - SHORT: SOUN 126 shares @ ~11.11
# INFO - 2025-12-16 - SHORT: SYM 22 shares @ ~62.69
# INFO - 2025-12-16 - SHORT: AXTI 108 shares @ ~13.00
# INFO - 2025-12-16 - SHORT: MLTX 91 shares @ ~15.34
# INFO - 2025-12-16 - SHORT: RDNT 19 shares @ ~71.22
# INFO - 2025-12-17 - BUY EXECUTED: TLRY @ 14.17
# INFO - 2025-12-17 - BUY EXECUTED: CLSK @ 12.14
# INFO - 2025-12-17 - BUY EXECUTED: OPCH @ 32.87
# INFO - 2025-12-17 - BUY EXECUTED: TLRY @ 14.17
# INFO - 2025-12-17 - BUY EXECUTED: WVE @ 16.35
# INFO - 2025-12-17 - BUY EXECUTED: ZBIO @ 36.66
# INFO - 2025-12-17 - SELL EXECUTED: SOUN @ 11.23
# INFO - 2025-12-17 - SELL EXECUTED: SYM @ 63.10
# INFO - 2025-12-17 - SELL EXECUTED: AXTI @ 14.01
# INFO - 2025-12-17 - SELL EXECUTED: MLTX @ 15.34
# INFO - 2025-12-17 - SELL EXECUTED: RDNT @ 71.00
# INFO - 2025-12-17 - TRADE CLOSED: TLRY PnL=-483.12 (-499.41 net)
# INFO - 2025-12-17 - TRADE CLOSED: CLSK PnL=-22.99 (-37.56 net)
# INFO - 2025-12-17 - TRADE CLOSED: OPCH PnL=27.95 (13.68 net)
# INFO - 2025-12-17 - TRADE CLOSED: WVE PnL=35.85 (21.12 net)
# INFO - 2025-12-17 - TRADE CLOSED: ZBIO PnL=-201.08 (-216.20 net)
# INFO - 2025-12-17 - Rebalancing: DD=74.5%, scale=0.25, targets=5
# INFO - 2025-12-17 - CLOSING: AXTI (not in bottom-K)
# INFO - 2025-12-17 - CLOSING: MLTX (not in bottom-K)
# INFO - 2025-12-17 - CLOSING: RDNT (not in bottom-K)
# INFO - 2025-12-17 - CLOSING: SOUN (not in bottom-K)
# INFO - 2025-12-17 - CLOSING: SYM (not in bottom-K)
# INFO - 2025-12-17 - CLOSING: TLRY (not in bottom-K)
# INFO - 2025-12-17 - SHORT: MARA 142 shares @ ~9.93
# INFO - 2025-12-17 - SHORT: CORZ 104 shares @ ~13.57
# INFO - 2025-12-17 - SHORT: RARE 42 shares @ ~33.21
# INFO - 2025-12-17 - SHORT: CLS 5 shares @ ~275.83
# INFO - 2025-12-17 - SHORT: BKSY 86 shares @ ~16.45
# INFO - 2025-12-18 - BUY EXECUTED: AXTI @ 13.51
# INFO - 2025-12-18 - BUY EXECUTED: MLTX @ 13.94
# INFO - 2025-12-18 - BUY EXECUTED: RDNT @ 72.05
# INFO - 2025-12-18 - BUY EXECUTED: SOUN @ 11.33
# INFO - 2025-12-18 - BUY EXECUTED: SYM @ 57.81
# INFO - 2025-12-18 - SELL EXECUTED: TLRY @ 13.50
# INFO - 2025-12-18 - SELL EXECUTED: MARA @ 10.20
# INFO - 2025-12-18 - SELL EXECUTED: CORZ @ 14.47
# INFO - 2025-12-18 - SELL EXECUTED: RARE @ 33.31
# INFO - 2025-12-18 - SELL EXECUTED: CLS @ 289.59
# INFO - 2025-12-18 - SELL EXECUTED: BKSY @ 17.05
# INFO - 2025-12-18 - TRADE CLOSED: AXTI PnL=54.00 (39.14 net)
# INFO - 2025-12-18 - TRADE CLOSED: MLTX PnL=127.40 (114.08 net)
# INFO - 2025-12-18 - TRADE CLOSED: RDNT PnL=-19.95 (-33.54 net)
# INFO - 2025-12-18 - TRADE CLOSED: SOUN PnL=-12.60 (-26.81 net)
# INFO - 2025-12-18 - TRADE CLOSED: SYM PnL=116.38 (103.08 net)
# INFO - 2025-12-18 - TRADE CLOSED: TLRY PnL=-88.44 (-106.70 net)
# INFO - 2025-12-18 - Rebalancing: DD=74.6%, scale=0.25, targets=5
# INFO - 2025-12-18 - CLOSING: CORZ (not in bottom-K)
# INFO - 2025-12-18 - CLOSING: MARA (not in bottom-K)
# INFO - 2025-12-18 - CLOSING: RARE (not in bottom-K)
# INFO - 2025-12-18 - CLOSING: BKSY (not in bottom-K)
# INFO - 2025-12-18 - CLOSING: CLS (not in bottom-K)
# INFO - 2025-12-18 - SHORT: BBAI 251 shares @ ~5.63
# INFO - 2025-12-18 - SHORT: FDMT 162 shares @ ~8.69
# INFO - 2025-12-18 - SHORT: ASX 95 shares @ ~14.87
# INFO - 2025-12-18 - SHORT: TLRY 114 shares @ ~12.34
# INFO - 2025-12-18 - SHORT: MBX 49 shares @ ~28.67
# INFO - Backtest complete
# INFO -   Final value: $28,295.08
# INFO -   Total return: -71.7%
# INFO -   Sharpe ratio: -1.00
# INFO -   Max drawdown: 78.2%
# INFO -   Total trades: 57
# CPU times: user 25min 21s, sys: 8.33 s, total: 25min 29s
# Wall time: 25min 5s

# %% [markdown]
# ## 2. Results Summary

# %%
print("=" * 50)
print("BACKTEST RESULTS")
print("=" * 50)
print(f"Period:       {START_DATE} to {END_DATE}")
print(f"Initial Cash: ${INITIAL_CASH:,.0f}")
print(f"Final Value:  ${result.final_value:,.2f}")
print(f"Total Return: {result.total_return*100:.1f}%")
print(f"Sharpe Ratio: {result.sharpe_ratio:.2f}" if result.sharpe_ratio else "Sharpe Ratio: N/A")
print(f"Max Drawdown: {result.max_drawdown*100:.1f}%")
print(f"Total Trades: {result.n_trades}")
print("=" * 50)
# Out:
# ==================================================
# BACKTEST RESULTS
# ==================================================
# Period:       2024-10-22 to 2025-12-18
# Initial Cash: $100,000
# Final Value:  $28,295.08
# Total Return: -71.7%
# Sharpe Ratio: -1.00
# Max Drawdown: 78.2%
# Total Trades: 57
# ==================================================

# %% [markdown]
# ## 3. Detailed Analyzer Output

# %%
# Trade analysis
trades = result.analyzers.get('trades', {})

if trades:
    print("Trade Analysis:")
    print(f"  Total trades: {trades.get('total', {}).get('total', 0)}")
    print(f"  Open trades:  {trades.get('total', {}).get('open', 0)}")
    print(f"  Closed trades: {trades.get('total', {}).get('closed', 0)}")
    
    won = trades.get('won', {})
    lost = trades.get('lost', {})
    
    if won.get('total', 0) + lost.get('total', 0) > 0:
        win_rate = won.get('total', 0) / (won.get('total', 0) + lost.get('total', 0))
        print(f"  Win rate: {win_rate*100:.1f}%")
        print(f"  Avg win:  ${won.get('pnl', {}).get('average', 0):.2f}")
        print(f"  Avg loss: ${lost.get('pnl', {}).get('average', 0):.2f}")
# Out:
# Trade Analysis:
#   Total trades: 57
#   Open trades:  5
#   Closed trades: 52
#   Win rate: 53.8%
#   Avg win:  $894.65
#   Avg loss: $-4035.79

# %%
# Drawdown analysis
dd = result.analyzers.get('drawdown', {})

if dd:
    print("Drawdown Analysis:")
    print(f"  Max drawdown: {dd.get('max', {}).get('drawdown', 0):.2f}%")
    print(f"  Max money down: ${dd.get('max', {}).get('moneydown', 0):,.2f}")
    print(f"  Max duration: {dd.get('max', {}).get('len', 0)} bars")
# Out:
# Drawdown Analysis:
#   Max drawdown: 78.19%
#   Max money down: $90,443.17
#   Max duration: 19 bars

# %%
# Returns analysis
returns = result.analyzers.get('returns', {})

if returns:
    print("Returns Analysis:")
    print(f"  Total return: {returns.get('rtot', 0)*100:.2f}%")
    print(f"  Avg daily return: {returns.get('ravg', 0)*100:.4f}%")
    print(f"  Annualized return: {returns.get('rnorm100', 0):.2f}%")
# Out:
# Returns Analysis:
#   Total return: -126.25%
#   Avg daily return: -0.4280%
#   Annualized return: -65.99%

# %% [markdown]
# ## 4. Compare Configurations
#
# Run multiple backtests with different settings.

# %%
# Define configurations to test
configs = [
    {"name": "Baseline (no scaling)", "use_dd_scaling": False, "use_confidence": False},
    {"name": "DD Scaling", "use_dd_scaling": True, "use_confidence": False},
    # {"name": "Confidence Weighted", "use_dd_scaling": False, "use_confidence": True},
    # {"name": "DD + Confidence", "use_dd_scaling": True, "use_confidence": True},
]

# Set to smaller number for comparison runs
COMPARE_MAX_SYMBOLS = MAX_SYMBOLS  # Use same as main backtest

# %%
# %%time

comparison_results = []

for cfg in configs:
    print(f"\nRunning: {cfg['name']}...")
    
    res = run_backtest(
        model_path=MODEL_PATH,
        data_dir=DATA_DIR,
        start_date=START_DATE,
        end_date=END_DATE,
        initial_cash=INITIAL_CASH,
        use_dd_scaling=cfg['use_dd_scaling'],
        use_confidence=cfg['use_confidence'],
        max_symbols=COMPARE_MAX_SYMBOLS,
    )
    
    comparison_results.append({
        'name': cfg['name'],
        'return': res.total_return,
        'sharpe': res.sharpe_ratio,
        'max_dd': res.max_drawdown,
        'n_trades': res.n_trades,
        'final_value': res.final_value,
    })
# Out:
# INFO - Starting backtest
# INFO -   Model: data/model_final.pt
# INFO -   Data: data
# INFO -   Period: 2024-10-22 to 2025-12-18
# INFO - Loaded model from data/model_final.pt
# INFO -   Price features: 9
# INFO -   Fund features: 19
# INFO -   Embedding dims: 768
# INFO - Loading price data from data/prices.pqt...
# Running: Baseline (no scaling)...
# INFO -   Loaded 5,888,410 rows
# INFO -   Splitting into per-symbol DataFrames...
# INFO -     Processed 1,000/5,644 symbols...

# %%
# Display comparison
comp_df = pd.DataFrame(comparison_results)
comp_df['return_pct'] = comp_df['return'] * 100
comp_df['max_dd_pct'] = comp_df['max_dd'] * 100

print("\n" + "=" * 70)
print("CONFIGURATION COMPARISON")
print("=" * 70)
print(comp_df[['name', 'return_pct', 'sharpe', 'max_dd_pct', 'n_trades']].to_string(index=False))

# %%
# Plot comparison
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Returns
ax = axes[0]
ax.bar(comp_df['name'], comp_df['return_pct'])
ax.set_ylabel('Return (%)')
ax.set_title('Total Return')
ax.tick_params(axis='x', rotation=45)

# Sharpe
ax = axes[1]
sharpe_vals = comp_df['sharpe'].fillna(0)
ax.bar(comp_df['name'], sharpe_vals)
ax.set_ylabel('Sharpe Ratio')
ax.set_title('Sharpe Ratio')
ax.tick_params(axis='x', rotation=45)

# Max DD
ax = axes[2]
ax.bar(comp_df['name'], comp_df['max_dd_pct'])
ax.set_ylabel('Max Drawdown (%)')
ax.set_title('Max Drawdown')
ax.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Compare with Notebook Backtest
#
# Load results from the original notebook backtest for comparison.

# %%
# Load notebook backtest results if available
notebook_results_path = DATA_DIR / 'short_backtest_improved.pqt'

if notebook_results_path.exists():
    nb_results = pd.read_parquet(notebook_results_path)
    print("Notebook backtest results:")
    display(nb_results)
else:
    print(f"No notebook results found at {notebook_results_path}")

# %% [markdown]
# ## 6. Notes
#
# **Key differences between backtrader and notebook backtests:**
#
# 1. **Order execution**: Backtrader simulates real order flow with fills on next bar
# 2. **Slippage**: Orders execute at open/close prices, not idealized prices
# 3. **Commission**: Applied per trade
# 4. **Short selling**: Proper margin and borrow mechanics
#
# **Performance notes:**
# - Loading all ~5000 symbols is slow (several minutes)
# - Use `max_symbols` for faster iteration during development
# - For accurate results, run with all symbols
