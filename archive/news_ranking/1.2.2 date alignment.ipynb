# %%
import pandas as pd
import numpy as np
from zoneinfo import ZoneInfo

# %%
ET = ZoneInfo("America/New_York")
CUTOFF_HOUR = 15
CUTOFF_MINUTE = 30

# %%
# Read the anonymized news (output of 1.2.1)
news = pd.read_parquet("data/all_the_news_anon.pqt")

# Filter to universe (symbols with fundamentals)
universe = pd.read_parquet("data/universe.pqt")
universe_symbols = set(universe["symbol"].unique())
n_before = len(news)
news = news[news["symbol"].isin(universe_symbols)]
n_after = len(news)
print(f"Filtered to universe: {n_before:,} -> {n_after:,} articles")

news.head()
# Out:
# Filtered to universe: 1,748,719 -> 1,747,711 articles
#   symbol        publishedDate                      publisher  \
# 0   APLT  2025-01-28 17:30:00                     Accesswire
# 1   MSFT  2021-08-25 23:42:48                       Benzinga
# 2    WDC  2025-10-23 11:05:51      Zacks Investment Research
# 3   NFLX  2025-07-17 17:10:12  Bloomberg Markets and Finance
# 4   AMZN  2024-04-30 16:37:10                        NYTimes
#
#                                                title  \
# 0  Class Action Filed Against Applied Therapeutic...
# 1  Apple Commits To Shoring Up Supply Chain Secur...
# 2  Western Digital (WDC) Expected to Beat Earning...
# 3             Netflix Reports Results | Closing Bell
# 4  Amazon Reports $143.3 Billion in Revenue for F...
#
#                                                image                site  \
# 0  https://images.financialmodelingprep.com/news/...  accessnewswire.com
# 1  https://images.financialmodelingprep.com/news/...        benzinga.com
# 2  https://images.financialmodelingprep.com/news/...           zacks.com
# 3  https://images.financialmodelingprep.com/news/...         youtube.com
# 4  https://images.financialmodelingprep.com/news/...         nytimes.com
#
#                                                 text  \
# 0  NEW YORK, NY / ACCESS Newswire / January 28, 2...
# 1  Apple Inc (NASDAQ: AAPL) is set to create a pr...
# 2  Western Digital (WDC) possesses the right comb...
# 3  Comprehensive cross-platform coverage of the U...
# 4  The company also reported that profit more tha...
#
#                                                  url window_from   window_to  \
# 0  https://www.accessnewswire.com/newsroom/en/bus...  2025-01-22  2025-02-21
# 1  https://www.benzinga.com/news/21/08/22668742/a...  2021-08-11  2021-09-10
# 2  https://www.zacks.com/stock/news/2775286/weste...  2025-10-19  2025-11-18
# 3        https://www.youtube.com/watch?v=hvlxOAoLEJ4  2025-06-21  2025-07-21
# 4  https://www.nytimes.com/2024/04/30/technology/...  2024-04-27  2024-05-27
#
#    page                                         title_anon  \
# 0     1  Class Action Filed Against __TARGET__ (__TARGE...
# 1     0  __OTHER__ Commits To Shoring Up Supply Chain S...
# 2     0  __TARGET__ (__TARGET__) Expected to __OTHER__ ...
# 3     0          __TARGET__ Reports Results | Closing Bell
# 4     1  Amazon Reports $143.3 Billion in Revenue for F...
#
#                                            text_anon
# 0  NEW YORK, NY / __OTHER__ / January 28, 2025 / ...
# 1  __OTHER__ Inc (__OTHER__: __OTHER__) is set to...
# 2  __TARGET__ (__TARGET__) possesses the right co...
# 3  Comprehensive cross-platform coverage of the U...
# 4  The company also reported that profit more tha...

# %%
def assign_trading_date(published: pd.Series, cutoff_hour: int = 15, cutoff_minute: int = 30) -> pd.Series:
    """Assign trading date based on 15:30 ET cutoff.
    
    Articles before cutoff -> same day
    Articles at/after cutoff -> next trading day
    Weekend articles -> Monday
    """
    # Ensure datetime
    dt = pd.to_datetime(published)
    
    # Localize to ET if naive, otherwise convert
    # Use ambiguous='NaT' for DST transition times, then forward-fill
    if dt.dt.tz is None:
        dt = dt.dt.tz_localize(ET, ambiguous='NaT', nonexistent='shift_forward')
        # Fill NaT (ambiguous times) with a reasonable default - treat as standard time
        dt = dt.fillna(method='ffill')
    else:
        dt = dt.dt.tz_convert(ET)
    
    # Time of day in minutes from midnight
    time_minutes = dt.dt.hour * 60 + dt.dt.minute
    cutoff_minutes = cutoff_hour * 60 + cutoff_minute
    
    # Base date (no time)
    base_date = dt.dt.normalize()
    
    # If at/after cutoff, push to next day
    after_cutoff = time_minutes >= cutoff_minutes
    trading_date = base_date + pd.to_timedelta(after_cutoff.astype(int), unit="D")
    
    # Handle weekends: Saturday(5) -> Monday, Sunday(6) -> Monday
    weekday = trading_date.dt.weekday
    trading_date = trading_date + pd.to_timedelta(
        np.where(weekday == 5, 2, np.where(weekday == 6, 1, 0)), unit="D"
    )
    
    return trading_date.dt.date

# %%
news["trading_date"] = assign_trading_date(news["publishedDate"], CUTOFF_HOUR, CUTOFF_MINUTE)
news[["publishedDate", "trading_date"]].head(20)
# Out:
# /tmp/ipykernel_639227/2379366237.py:16: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dt = dt.fillna(method='ffill')
#           publishedDate trading_date
# 0   2025-01-28 17:30:00   2025-01-29
# 1   2021-08-25 23:42:48   2021-08-26
# 2   2025-10-23 11:05:51   2025-10-23
# 3   2025-07-17 17:10:12   2025-07-18
# 4   2024-04-30 16:37:10   2024-05-01
# 5   2022-01-03 13:25:10   2022-01-03
# 6   2022-10-26 13:20:00   2022-10-26
# 7   2023-12-13 16:05:00   2023-12-14
# 8   2024-05-13 13:01:25   2024-05-13
# 9   2024-05-01 14:55:13   2024-05-01
# 10  2023-05-23 07:53:04   2023-05-23
# 11  2023-07-24 07:00:44   2023-07-24
# 12  2021-12-08 15:59:00   2021-12-09
# 13  2024-07-10 18:52:04   2024-07-11
# 14  2025-01-17 01:50:00   2025-01-17
# 15  2023-03-02 09:30:00   2023-03-02
# 16  2021-02-11 21:29:00   2021-02-12
# 17  2025-12-04 09:44:17   2025-12-04
# 18  2022-03-17 12:55:03   2022-03-17
# 19  2022-05-20 14:28:00   2022-05-20

# %%
# Verify distribution
news["trading_date"].value_counts().sort_index().tail(20)
# Out:
# trading_date
# 2025-11-24    2823
# 2025-11-25    2280
# 2025-11-26    2118
# 2025-11-27    1685
# 2025-11-28    1268
# 2025-12-01    3192
# 2025-12-02    2285
# 2025-12-03    2235
# 2025-12-04    2570
# 2025-12-05    2069
# 2025-12-08    3501
# 2025-12-09    1939
# 2025-12-10    2377
# 2025-12-11    2263
# 2025-12-12    2202
# 2025-12-15    3588
# 2025-12-16    2047
# 2025-12-17    2150
# 2025-12-18    2293
# 2025-12-19     400
# Name: count, dtype: int64

# %%
# Check no weekends in trading_date
td = pd.to_datetime(news["trading_date"])
print(f"Saturday count: {(td.dt.weekday == 5).sum()}")
print(f"Sunday count: {(td.dt.weekday == 6).sum()}")
# Out:
# Saturday count: 0
# Sunday count: 4252

# %%
# Save filtered news with trading_date back to anonymized file
news.to_parquet("data/all_the_news_anon.pqt", index=False)
print(f"Saved {len(news):,} articles to all_the_news_anon.pqt")
# Out:
# Saved 1,747,711 articles to all_the_news_anon.pqt
