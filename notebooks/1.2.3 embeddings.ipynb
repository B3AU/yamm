# %%
import pandas as pd
import numpy as np
from multiprocessing import Pool, cpu_count
from tqdm.auto import tqdm

# %%
MODEL_NAME = "BAAI/bge-base-en-v1.5"
BATCH_SIZE = 64
N_WORKERS = cpu_count()-2
SAVE_EVERY = 1_000  # Save checkpoint every N articles

# %%
news = pd.read_parquet("data/all_the_news_anon.pqt")
print(f"{len(news):,} articles")
news.head()
# Out:
# 1,747,711 articles
#   symbol        publishedDate                      publisher  \
# 0   APLT  2025-01-28 17:30:00                     Accesswire
# 1   MSFT  2021-08-25 23:42:48                       Benzinga
# 2    WDC  2025-10-23 11:05:51      Zacks Investment Research
# 3   NFLX  2025-07-17 17:10:12  Bloomberg Markets and Finance
# 4   AMZN  2024-04-30 16:37:10                        NYTimes
#
#                                                title  \
# 0  Class Action Filed Against Applied Therapeutic...
# 1  Apple Commits To Shoring Up Supply Chain Secur...
# 2  Western Digital (WDC) Expected to Beat Earning...
# 3             Netflix Reports Results | Closing Bell
# 4  Amazon Reports $143.3 Billion in Revenue for F...
#
#                                                image                site  \
# 0  https://images.financialmodelingprep.com/news/...  accessnewswire.com
# 1  https://images.financialmodelingprep.com/news/...        benzinga.com
# 2  https://images.financialmodelingprep.com/news/...           zacks.com
# 3  https://images.financialmodelingprep.com/news/...         youtube.com
# 4  https://images.financialmodelingprep.com/news/...         nytimes.com
#
#                                                 text  \
# 0  NEW YORK, NY / ACCESS Newswire / January 28, 2...
# 1  Apple Inc (NASDAQ: AAPL) is set to create a pr...
# 2  Western Digital (WDC) possesses the right comb...
# 3  Comprehensive cross-platform coverage of the U...
# 4  The company also reported that profit more tha...
#
#                                                  url window_from   window_to  \
# 0  https://www.accessnewswire.com/newsroom/en/bus...  2025-01-22  2025-02-21
# 1  https://www.benzinga.com/news/21/08/22668742/a...  2021-08-11  2021-09-10
# 2  https://www.zacks.com/stock/news/2775286/weste...  2025-10-19  2025-11-18
# 3        https://www.youtube.com/watch?v=hvlxOAoLEJ4  2025-06-21  2025-07-21
# 4  https://www.nytimes.com/2024/04/30/technology/...  2024-04-27  2024-05-27
#
#    page                                         title_anon  \
# 0     1  Class Action Filed Against __TARGET__ (__TARGE...
# 1     0  __OTHER__ Commits To Shoring Up Supply Chain S...
# 2     0  __TARGET__ (__TARGET__) Expected to __OTHER__ ...
# 3     0          __TARGET__ Reports Results | Closing Bell
# 4     1  Amazon Reports $143.3 Billion in Revenue for F...
#
#                                            text_anon trading_date
# 0  NEW YORK, NY / __OTHER__ / January 28, 2025 / ...   2025-01-29
# 1  __OTHER__ Inc (__OTHER__: __OTHER__) is set to...   2021-08-26
# 2  __TARGET__ (__TARGET__) possesses the right co...   2025-10-23
# 3  Comprehensive cross-platform coverage of the U...   2025-07-18
# 4  The company also reported that profit more tha...   2024-05-01

# %%
# Check for and drop duplicate (url, symbol) pairs
n_dups = news.duplicated(subset=["url", "symbol"]).sum()
if n_dups > 0:
    print(f"Dropping {n_dups:,} duplicate (url, symbol) pairs")
    news = news.drop_duplicates(subset=["url", "symbol"], keep="first")

# Check for existing embeddings to skip
EMBEDDINGS_PATH = "data/news_embeddings.pqt"
try:
    existing = pd.read_parquet(EMBEDDINGS_PATH)
    already_done = set(zip(existing["url"], existing["symbol"]))
    print(f"Found {len(already_done):,} existing embeddings")
except FileNotFoundError:
    already_done = set()
    print("No existing embeddings found")

# Filter to only new articles
news["_key"] = list(zip(news["url"], news["symbol"]))
to_embed = news[~news["_key"].isin(already_done)].copy()
to_embed.drop(columns=["_key"], inplace=True)
news.drop(columns=["_key"], inplace=True)
print(f"{len(to_embed):,} articles to embed")
# Out:
# Dropping 2 duplicate (url, symbol) pairs
# Found 1,306,998 existing embeddings
# 441,151 articles to embed

# %%
# Combine title + text for embedding
texts = (to_embed["title_anon"].fillna("") + " " + to_embed["text_anon"].fillna("")).str.strip().tolist()
urls = to_embed["url"].tolist()
symbols = to_embed["symbol"].tolist()
print(f"Avg length: {np.mean([len(t) for t in texts]):.0f} chars")

# Split into chunks for workers
def chunk_list(lst: list, n_chunks: int) -> list[list]:
    k, m = divmod(len(lst), n_chunks)
    return [lst[i * k + min(i, m):(i + 1) * k + min(i + 1, m)] for i in range(n_chunks)]
# Out:
# Avg length: 643 chars

# %%
# Worker function - each process loads its own model
def embed_chunk(args: tuple[int, list[str], str, int]) -> tuple[int, np.ndarray]:
    chunk_id, texts, model_name, batch_size = args
    
    from sentence_transformers import SentenceTransformer
    model = SentenceTransformer(model_name)
    
    embeddings = model.encode(
        texts,
        batch_size=batch_size,
        show_progress_bar=True,
        normalize_embeddings=True,
    )
    return chunk_id, embeddings

# %%
def embed_batch_parallel(texts: list[str], urls: list[str], symbols: list[str]) -> pd.DataFrame:
    """Embed a batch of texts using multiprocessing and return a dataframe."""
    text_chunks = chunk_list(texts, N_WORKERS)
    args = [(i, tc, MODEL_NAME, BATCH_SIZE) for i, tc in enumerate(text_chunks)]
    
    with Pool(N_WORKERS) as pool:
        results = pool.map(embed_chunk, args)
    
    # Reassemble in order
    results.sort(key=lambda x: x[0])
    embeddings = np.vstack([r[1] for r in results])
    
    # Build dataframe
    emb_cols = [f"emb_{i}" for i in range(embeddings.shape[1])]
    df = pd.DataFrame(embeddings, columns=emb_cols)
    df["url"] = urls
    df["symbol"] = symbols
    return df[["url", "symbol"] + emb_cols]

# %%
if len(texts) == 0:
    print("Nothing to embed")
else:
    n_total = len(texts)
    n_batches = (n_total + SAVE_EVERY - 1) // SAVE_EVERY
    
    # Load existing for appending
    try:
        existing_df = pd.read_parquet(EMBEDDINGS_PATH)
        all_dfs = [existing_df]
        print(f"Loaded {len(existing_df):,} existing embeddings")
    except FileNotFoundError:
        all_dfs = []
    
    print(f"Processing {n_total:,} articles in {n_batches} batches of ~{SAVE_EVERY:,}")
    print(f"Using {N_WORKERS} workers")
    print("-" * 60)
    
    for batch_idx in range(n_batches):
        batch_start = batch_idx * SAVE_EVERY
        batch_end = min(batch_start + SAVE_EVERY, n_total)
        
        batch_texts = texts[batch_start:batch_end]
        batch_urls = urls[batch_start:batch_end]
        batch_symbols = symbols[batch_start:batch_end]
        
        print(f"\nBatch {batch_idx + 1}/{n_batches}: articles {batch_start:,} - {batch_end:,} ({len(batch_texts):,} texts)")
        
        batch_df = embed_batch_parallel(batch_texts, batch_urls, batch_symbols)
        all_dfs.append(batch_df)
        
        # Save checkpoint
        combined = pd.concat(all_dfs, ignore_index=True)
        combined.to_parquet(EMBEDDINGS_PATH, index=False)
        
        done = batch_end
        pct = done / n_total * 100
        print(f"Progress: {done:,}/{n_total:,} ({pct:.1f}%) - checkpoint saved")
    
    print("-" * 60)
    print(f"Done! Total embeddings: {len(combined):,}")
# Out:
# Loaded 1,306,998 existing embeddings
# Processing 441,151 articles in 442 batches of ~1,000
# Using 18 workers
# ------------------------------------------------------------
#
# Batch 1/442: articles 0 - 1,000 (1,000 texts)
# Progress: 1,000/441,151 (0.2%) - checkpoint saved
#
# Batch 2/442: articles 1,000 - 2,000 (1,000 texts)
# Progress: 2,000/441,151 (0.5%) - checkpoint saved
#
# Batch 3/442: articles 2,000 - 3,000 (1,000 texts)
# Progress: 3,000/441,151 (0.7%) - checkpoint saved
#
# Batch 4/442: articles 3,000 - 4,000 (1,000 texts)
# Progress: 4,000/441,151 (0.9%) - checkpoint saved
#
# Batch 5/442: articles 4,000 - 5,000 (1,000 texts)
# Progress: 5,000/441,151 (1.1%) - checkpoint saved
#
# Batch 6/442: articles 5,000 - 6,000 (1,000 texts)
# Progress: 6,000/441,151 (1.4%) - checkpoint saved
#
# Batch 7/442: articles 6,000 - 7,000 (1,000 texts)
# Progress: 7,000/441,151 (1.6%) - checkpoint saved
#
# Batch 8/442: articles 7,000 - 8,000 (1,000 texts)
# Progress: 8,000/441,151 (1.8%) - checkpoint saved
#
# Batch 9/442: articles 8,000 - 9,000 (1,000 texts)
# Progress: 9,000/441,151 (2.0%) - checkpoint saved
#
# Batch 10/442: articles 9,000 - 10,000 (1,000 texts)
# Progress: 10,000/441,151 (2.3%) - checkpoint saved
#
# Batch 11/442: articles 10,000 - 11,000 (1,000 texts)
# Progress: 11,000/441,151 (2.5%) - checkpoint saved
#
# Batch 12/442: articles 11,000 - 12,000 (1,000 texts)
# Progress: 12,000/441,151 (2.7%) - checkpoint saved
#
# Batch 13/442: articles 12,000 - 13,000 (1,000 texts)
# Progress: 13,000/441,151 (2.9%) - checkpoint saved
#
# Batch 14/442: articles 13,000 - 14,000 (1,000 texts)
# Progress: 14,000/441,151 (3.2%) - checkpoint saved
#
# Batch 15/442: articles 14,000 - 15,000 (1,000 texts)
# Progress: 15,000/441,151 (3.4%) - checkpoint saved
#
# Batch 16/442: articles 15,000 - 16,000 (1,000 texts)
# Progress: 16,000/441,151 (3.6%) - checkpoint saved
#
# Batch 17/442: articles 16,000 - 17,000 (1,000 texts)
# Progress: 17,000/441,151 (3.9%) - checkpoint saved
#
# Batch 18/442: articles 17,000 - 18,000 (1,000 texts)
# Progress: 18,000/441,151 (4.1%) - checkpoint saved
#
# Batch 19/442: articles 18,000 - 19,000 (1,000 texts)
# Progress: 19,000/441,151 (4.3%) - checkpoint saved
#
# Batch 20/442: articles 19,000 - 20,000 (1,000 texts)
# Progress: 20,000/441,151 (4.5%) - checkpoint saved
#
# Batch 21/442: articles 20,000 - 21,000 (1,000 texts)
# Progress: 21,000/441,151 (4.8%) - checkpoint saved
#
# Batch 22/442: articles 21,000 - 22,000 (1,000 texts)
# Progress: 22,000/441,151 (5.0%) - checkpoint saved
#
# Batch 23/442: articles 22,000 - 23,000 (1,000 texts)
# Progress: 23,000/441,151 (5.2%) - checkpoint saved
#
# Batch 24/442: articles 23,000 - 24,000 (1,000 texts)
# Progress: 24,000/441,151 (5.4%) - checkpoint saved
#
# Batch 25/442: articles 24,000 - 25,000 (1,000 texts)
# Progress: 25,000/441,151 (5.7%) - checkpoint saved
#
# Batch 26/442: articles 25,000 - 26,000 (1,000 texts)
# Progress: 26,000/441,151 (5.9%) - checkpoint saved
#
# Batch 27/442: articles 26,000 - 27,000 (1,000 texts)
# Progress: 27,000/441,151 (6.1%) - checkpoint saved
#
# Batch 28/442: articles 27,000 - 28,000 (1,000 texts)
# Progress: 28,000/441,151 (6.3%) - checkpoint saved
#
# Batch 29/442: articles 28,000 - 29,000 (1,000 texts)
# Progress: 29,000/441,151 (6.6%) - checkpoint saved
#
# Batch 30/442: articles 29,000 - 30,000 (1,000 texts)
# Progress: 30,000/441,151 (6.8%) - checkpoint saved
#
# Batch 31/442: articles 30,000 - 31,000 (1,000 texts)
# Progress: 31,000/441,151 (7.0%) - checkpoint saved
#
# Batch 32/442: articles 31,000 - 32,000 (1,000 texts)
# Progress: 32,000/441,151 (7.3%) - checkpoint saved
#
# Batch 33/442: articles 32,000 - 33,000 (1,000 texts)
# Progress: 33,000/441,151 (7.5%) - checkpoint saved
#
# Batch 34/442: articles 33,000 - 34,000 (1,000 texts)
# Progress: 34,000/441,151 (7.7%) - checkpoint saved
#
# Batch 35/442: articles 34,000 - 35,000 (1,000 texts)
# Progress: 35,000/441,151 (7.9%) - checkpoint saved
#
# Batch 36/442: articles 35,000 - 36,000 (1,000 texts)
# Progress: 36,000/441,151 (8.2%) - checkpoint saved
#
# Batch 37/442: articles 36,000 - 37,000 (1,000 texts)
# Progress: 37,000/441,151 (8.4%) - checkpoint saved
#
# Batch 38/442: articles 37,000 - 38,000 (1,000 texts)
# Progress: 38,000/441,151 (8.6%) - checkpoint saved
#
# Batch 39/442: articles 38,000 - 39,000 (1,000 texts)
# Progress: 39,000/441,151 (8.8%) - checkpoint saved
#
# Batch 40/442: articles 39,000 - 40,000 (1,000 texts)
# Progress: 40,000/441,151 (9.1%) - checkpoint saved
#
# Batch 41/442: articles 40,000 - 41,000 (1,000 texts)
# Progress: 41,000/441,151 (9.3%) - checkpoint saved
#
# Batch 42/442: articles 41,000 - 42,000 (1,000 texts)
# Progress: 42,000/441,151 (9.5%) - checkpoint saved
#
# Batch 43/442: articles 42,000 - 43,000 (1,000 texts)
# Progress: 43,000/441,151 (9.7%) - checkpoint saved
#
# Batch 44/442: articles 43,000 - 44,000 (1,000 texts)
# Progress: 44,000/441,151 (10.0%) - checkpoint saved
#
# Batch 45/442: articles 44,000 - 45,000 (1,000 texts)
# Progress: 45,000/441,151 (10.2%) - checkpoint saved
#
# Batch 46/442: articles 45,000 - 46,000 (1,000 texts)
# Progress: 46,000/441,151 (10.4%) - checkpoint saved
#
# Batch 47/442: articles 46,000 - 47,000 (1,000 texts)
# Progress: 47,000/441,151 (10.7%) - checkpoint saved
#
# Batch 48/442: articles 47,000 - 48,000 (1,000 texts)
# Progress: 48,000/441,151 (10.9%) - checkpoint saved
#
# Batch 49/442: articles 48,000 - 49,000 (1,000 texts)
# Progress: 49,000/441,151 (11.1%) - checkpoint saved
#
# Batch 50/442: articles 49,000 - 50,000 (1,000 texts)
# Progress: 50,000/441,151 (11.3%) - checkpoint saved
#
# Batch 51/442: articles 50,000 - 51,000 (1,000 texts)
# Progress: 51,000/441,151 (11.6%) - checkpoint saved
#
# Batch 52/442: articles 51,000 - 52,000 (1,000 texts)
# Progress: 52,000/441,151 (11.8%) - checkpoint saved
#
# Batch 53/442: articles 52,000 - 53,000 (1,000 texts)
# Progress: 53,000/441,151 (12.0%) - checkpoint saved
#
# Batch 54/442: articles 53,000 - 54,000 (1,000 texts)
# Progress: 54,000/441,151 (12.2%) - checkpoint saved
#
# Batch 55/442: articles 54,000 - 55,000 (1,000 texts)
# Progress: 55,000/441,151 (12.5%) - checkpoint saved
#
# Batch 56/442: articles 55,000 - 56,000 (1,000 texts)
# Progress: 56,000/441,151 (12.7%) - checkpoint saved
#
# Batch 57/442: articles 56,000 - 57,000 (1,000 texts)
# Progress: 57,000/441,151 (12.9%) - checkpoint saved
#
# Batch 58/442: articles 57,000 - 58,000 (1,000 texts)
# Progress: 58,000/441,151 (13.1%) - checkpoint saved
#
# Batch 59/442: articles 58,000 - 59,000 (1,000 texts)
# Progress: 59,000/441,151 (13.4%) - checkpoint saved
#
# Batch 60/442: articles 59,000 - 60,000 (1,000 texts)
# Progress: 60,000/441,151 (13.6%) - checkpoint saved
#
# Batch 61/442: articles 60,000 - 61,000 (1,000 texts)
# Progress: 61,000/441,151 (13.8%) - checkpoint saved
#
# Batch 62/442: articles 61,000 - 62,000 (1,000 texts)
# Progress: 62,000/441,151 (14.1%) - checkpoint saved
#
# Batch 63/442: articles 62,000 - 63,000 (1,000 texts)
# Progress: 63,000/441,151 (14.3%) - checkpoint saved
#
# Batch 64/442: articles 63,000 - 64,000 (1,000 texts)
# Progress: 64,000/441,151 (14.5%) - checkpoint saved
#
# Batch 65/442: articles 64,000 - 65,000 (1,000 texts)
# Progress: 65,000/441,151 (14.7%) - checkpoint saved
#
# Batch 66/442: articles 65,000 - 66,000 (1,000 texts)
# Progress: 66,000/441,151 (15.0%) - checkpoint saved
#
# Batch 67/442: articles 66,000 - 67,000 (1,000 texts)
# Progress: 67,000/441,151 (15.2%) - checkpoint saved
#
# Batch 68/442: articles 67,000 - 68,000 (1,000 texts)
# Progress: 68,000/441,151 (15.4%) - checkpoint saved
#
# Batch 69/442: articles 68,000 - 69,000 (1,000 texts)
# Progress: 69,000/441,151 (15.6%) - checkpoint saved
#
# Batch 70/442: articles 69,000 - 70,000 (1,000 texts)
# Progress: 70,000/441,151 (15.9%) - checkpoint saved
#
# Batch 71/442: articles 70,000 - 71,000 (1,000 texts)
# Progress: 71,000/441,151 (16.1%) - checkpoint saved
#
# Batch 72/442: articles 71,000 - 72,000 (1,000 texts)
# Progress: 72,000/441,151 (16.3%) - checkpoint saved
#
# Batch 73/442: articles 72,000 - 73,000 (1,000 texts)
# Progress: 73,000/441,151 (16.5%) - checkpoint saved
#
# Batch 74/442: articles 73,000 - 74,000 (1,000 texts)
# Progress: 74,000/441,151 (16.8%) - checkpoint saved
#
# Batch 75/442: articles 74,000 - 75,000 (1,000 texts)
# Progress: 75,000/441,151 (17.0%) - checkpoint saved
#
# Batch 76/442: articles 75,000 - 76,000 (1,000 texts)
# Progress: 76,000/441,151 (17.2%) - checkpoint saved
#
# Batch 77/442: articles 76,000 - 77,000 (1,000 texts)
# Progress: 77,000/441,151 (17.5%) - checkpoint saved
#
# Batch 78/442: articles 77,000 - 78,000 (1,000 texts)
# Progress: 78,000/441,151 (17.7%) - checkpoint saved
#
# Batch 79/442: articles 78,000 - 79,000 (1,000 texts)
# Progress: 79,000/441,151 (17.9%) - checkpoint saved
#
# Batch 80/442: articles 79,000 - 80,000 (1,000 texts)
# Progress: 80,000/441,151 (18.1%) - checkpoint saved
#
# Batch 81/442: articles 80,000 - 81,000 (1,000 texts)
# Progress: 81,000/441,151 (18.4%) - checkpoint saved
#
# Batch 82/442: articles 81,000 - 82,000 (1,000 texts)
# Progress: 82,000/441,151 (18.6%) - checkpoint saved
#
# Batch 83/442: articles 82,000 - 83,000 (1,000 texts)
# Progress: 83,000/441,151 (18.8%) - checkpoint saved
#
# Batch 84/442: articles 83,000 - 84,000 (1,000 texts)
# Progress: 84,000/441,151 (19.0%) - checkpoint saved
#
# Batch 85/442: articles 84,000 - 85,000 (1,000 texts)
# Progress: 85,000/441,151 (19.3%) - checkpoint saved
#
# Batch 86/442: articles 85,000 - 86,000 (1,000 texts)
# Progress: 86,000/441,151 (19.5%) - checkpoint saved
#
# Batch 87/442: articles 86,000 - 87,000 (1,000 texts)
# Progress: 87,000/441,151 (19.7%) - checkpoint saved
#
# Batch 88/442: articles 87,000 - 88,000 (1,000 texts)
# Progress: 88,000/441,151 (19.9%) - checkpoint saved
#
# Batch 89/442: articles 88,000 - 89,000 (1,000 texts)
# Progress: 89,000/441,151 (20.2%) - checkpoint saved
#
# Batch 90/442: articles 89,000 - 90,000 (1,000 texts)
# Progress: 90,000/441,151 (20.4%) - checkpoint saved
#
# Batch 91/442: articles 90,000 - 91,000 (1,000 texts)
# Progress: 91,000/441,151 (20.6%) - checkpoint saved
#
# Batch 92/442: articles 91,000 - 92,000 (1,000 texts)
# Progress: 92,000/441,151 (20.9%) - checkpoint saved
#
# Batch 93/442: articles 92,000 - 93,000 (1,000 texts)
# Progress: 93,000/441,151 (21.1%) - checkpoint saved
#
# Batch 94/442: articles 93,000 - 94,000 (1,000 texts)
# Progress: 94,000/441,151 (21.3%) - checkpoint saved
#
# Batch 95/442: articles 94,000 - 95,000 (1,000 texts)
# Progress: 95,000/441,151 (21.5%) - checkpoint saved
#
# Batch 96/442: articles 95,000 - 96,000 (1,000 texts)
# Progress: 96,000/441,151 (21.8%) - checkpoint saved
#
# Batch 97/442: articles 96,000 - 97,000 (1,000 texts)
# Progress: 97,000/441,151 (22.0%) - checkpoint saved
#
# Batch 98/442: articles 97,000 - 98,000 (1,000 texts)
# Progress: 98,000/441,151 (22.2%) - checkpoint saved
#
# Batch 99/442: articles 98,000 - 99,000 (1,000 texts)
# Progress: 99,000/441,151 (22.4%) - checkpoint saved
#
# Batch 100/442: articles 99,000 - 100,000 (1,000 texts)
# Progress: 100,000/441,151 (22.7%) - checkpoint saved
#
# Batch 101/442: articles 100,000 - 101,000 (1,000 texts)
# Progress: 101,000/441,151 (22.9%) - checkpoint saved
#
# Batch 102/442: articles 101,000 - 102,000 (1,000 texts)
# Progress: 102,000/441,151 (23.1%) - checkpoint saved
#
# Batch 103/442: articles 102,000 - 103,000 (1,000 texts)
# Progress: 103,000/441,151 (23.3%) - checkpoint saved
#
# Batch 104/442: articles 103,000 - 104,000 (1,000 texts)
# Progress: 104,000/441,151 (23.6%) - checkpoint saved
#
# Batch 105/442: articles 104,000 - 105,000 (1,000 texts)
# Progress: 105,000/441,151 (23.8%) - checkpoint saved
#
# Batch 106/442: articles 105,000 - 106,000 (1,000 texts)
# Progress: 106,000/441,151 (24.0%) - checkpoint saved
#
# Batch 107/442: articles 106,000 - 107,000 (1,000 texts)
# Progress: 107,000/441,151 (24.3%) - checkpoint saved
#
# Batch 108/442: articles 107,000 - 108,000 (1,000 texts)
# Progress: 108,000/441,151 (24.5%) - checkpoint saved
#
# Batch 109/442: articles 108,000 - 109,000 (1,000 texts)
# Progress: 109,000/441,151 (24.7%) - checkpoint saved
#
# Batch 110/442: articles 109,000 - 110,000 (1,000 texts)
# Progress: 110,000/441,151 (24.9%) - checkpoint saved
#
# Batch 111/442: articles 110,000 - 111,000 (1,000 texts)
# Progress: 111,000/441,151 (25.2%) - checkpoint saved
#
# Batch 112/442: articles 111,000 - 112,000 (1,000 texts)
# Progress: 112,000/441,151 (25.4%) - checkpoint saved
#
# Batch 113/442: articles 112,000 - 113,000 (1,000 texts)
# Progress: 113,000/441,151 (25.6%) - checkpoint saved
#
# Batch 114/442: articles 113,000 - 114,000 (1,000 texts)
# Progress: 114,000/441,151 (25.8%) - checkpoint saved
#
# Batch 115/442: articles 114,000 - 115,000 (1,000 texts)
# Progress: 115,000/441,151 (26.1%) - checkpoint saved
#
# Batch 116/442: articles 115,000 - 116,000 (1,000 texts)
# Progress: 116,000/441,151 (26.3%) - checkpoint saved
#
# Batch 117/442: articles 116,000 - 117,000 (1,000 texts)
# Progress: 117,000/441,151 (26.5%) - checkpoint saved
#
# Batch 118/442: articles 117,000 - 118,000 (1,000 texts)
# Progress: 118,000/441,151 (26.7%) - checkpoint saved
#
# Batch 119/442: articles 118,000 - 119,000 (1,000 texts)
# Progress: 119,000/441,151 (27.0%) - checkpoint saved
#
# Batch 120/442: articles 119,000 - 120,000 (1,000 texts)
# Progress: 120,000/441,151 (27.2%) - checkpoint saved
#
# Batch 121/442: articles 120,000 - 121,000 (1,000 texts)
# Progress: 121,000/441,151 (27.4%) - checkpoint saved
#
# Batch 122/442: articles 121,000 - 122,000 (1,000 texts)
# Progress: 122,000/441,151 (27.7%) - checkpoint saved
#
# Batch 123/442: articles 122,000 - 123,000 (1,000 texts)
# Progress: 123,000/441,151 (27.9%) - checkpoint saved
#
# Batch 124/442: articles 123,000 - 124,000 (1,000 texts)
# Progress: 124,000/441,151 (28.1%) - checkpoint saved
#
# Batch 125/442: articles 124,000 - 125,000 (1,000 texts)
# Progress: 125,000/441,151 (28.3%) - checkpoint saved
#
# Batch 126/442: articles 125,000 - 126,000 (1,000 texts)
# Progress: 126,000/441,151 (28.6%) - checkpoint saved
#
# Batch 127/442: articles 126,000 - 127,000 (1,000 texts)
# Progress: 127,000/441,151 (28.8%) - checkpoint saved
#
# Batch 128/442: articles 127,000 - 128,000 (1,000 texts)
# Progress: 128,000/441,151 (29.0%) - checkpoint saved
#
# Batch 129/442: articles 128,000 - 129,000 (1,000 texts)
# Progress: 129,000/441,151 (29.2%) - checkpoint saved
#
# Batch 130/442: articles 129,000 - 130,000 (1,000 texts)
# Progress: 130,000/441,151 (29.5%) - checkpoint saved
#
# Batch 131/442: articles 130,000 - 131,000 (1,000 texts)
# Progress: 131,000/441,151 (29.7%) - checkpoint saved
#
# Batch 132/442: articles 131,000 - 132,000 (1,000 texts)
# Progress: 132,000/441,151 (29.9%) - checkpoint saved
#
# Batch 133/442: articles 132,000 - 133,000 (1,000 texts)
# Progress: 133,000/441,151 (30.1%) - checkpoint saved
#
# Batch 134/442: articles 133,000 - 134,000 (1,000 texts)
# Progress: 134,000/441,151 (30.4%) - checkpoint saved
#
# Batch 135/442: articles 134,000 - 135,000 (1,000 texts)
# Progress: 135,000/441,151 (30.6%) - checkpoint saved
#
# Batch 136/442: articles 135,000 - 136,000 (1,000 texts)
# Progress: 136,000/441,151 (30.8%) - checkpoint saved
#
# Batch 137/442: articles 136,000 - 137,000 (1,000 texts)
# Progress: 137,000/441,151 (31.1%) - checkpoint saved
#
# Batch 138/442: articles 137,000 - 138,000 (1,000 texts)
# Progress: 138,000/441,151 (31.3%) - checkpoint saved
#
# Batch 139/442: articles 138,000 - 139,000 (1,000 texts)
# Progress: 139,000/441,151 (31.5%) - checkpoint saved
#
# Batch 140/442: articles 139,000 - 140,000 (1,000 texts)
# Progress: 140,000/441,151 (31.7%) - checkpoint saved
#
# Batch 141/442: articles 140,000 - 141,000 (1,000 texts)
# Progress: 141,000/441,151 (32.0%) - checkpoint saved
#
# Batch 142/442: articles 141,000 - 142,000 (1,000 texts)
# Progress: 142,000/441,151 (32.2%) - checkpoint saved
#
# Batch 143/442: articles 142,000 - 143,000 (1,000 texts)
# Progress: 143,000/441,151 (32.4%) - checkpoint saved
#
# Batch 144/442: articles 143,000 - 144,000 (1,000 texts)
# Progress: 144,000/441,151 (32.6%) - checkpoint saved
#
# Batch 145/442: articles 144,000 - 145,000 (1,000 texts)
# Progress: 145,000/441,151 (32.9%) - checkpoint saved
#
# Batch 146/442: articles 145,000 - 146,000 (1,000 texts)
# Progress: 146,000/441,151 (33.1%) - checkpoint saved
#
# Batch 147/442: articles 146,000 - 147,000 (1,000 texts)
# Progress: 147,000/441,151 (33.3%) - checkpoint saved
#
# Batch 148/442: articles 147,000 - 148,000 (1,000 texts)
# Progress: 148,000/441,151 (33.5%) - checkpoint saved
#
# Batch 149/442: articles 148,000 - 149,000 (1,000 texts)
# Progress: 149,000/441,151 (33.8%) - checkpoint saved
#
# Batch 150/442: articles 149,000 - 150,000 (1,000 texts)
# Progress: 150,000/441,151 (34.0%) - checkpoint saved
#
# Batch 151/442: articles 150,000 - 151,000 (1,000 texts)
# Progress: 151,000/441,151 (34.2%) - checkpoint saved
#
# Batch 152/442: articles 151,000 - 152,000 (1,000 texts)
# Progress: 152,000/441,151 (34.5%) - checkpoint saved
#
# Batch 153/442: articles 152,000 - 153,000 (1,000 texts)
# Progress: 153,000/441,151 (34.7%) - checkpoint saved
#
# Batch 154/442: articles 153,000 - 154,000 (1,000 texts)
# Progress: 154,000/441,151 (34.9%) - checkpoint saved
#
# Batch 155/442: articles 154,000 - 155,000 (1,000 texts)
# Progress: 155,000/441,151 (35.1%) - checkpoint saved
#
# Batch 156/442: articles 155,000 - 156,000 (1,000 texts)
# Progress: 156,000/441,151 (35.4%) - checkpoint saved
#
# Batch 157/442: articles 156,000 - 157,000 (1,000 texts)
# Progress: 157,000/441,151 (35.6%) - checkpoint saved
#
# Batch 158/442: articles 157,000 - 158,000 (1,000 texts)
# Progress: 158,000/441,151 (35.8%) - checkpoint saved
#
# Batch 159/442: articles 158,000 - 159,000 (1,000 texts)
# Progress: 159,000/441,151 (36.0%) - checkpoint saved
#
# Batch 160/442: articles 159,000 - 160,000 (1,000 texts)
# Progress: 160,000/441,151 (36.3%) - checkpoint saved
#
# Batch 161/442: articles 160,000 - 161,000 (1,000 texts)
# Progress: 161,000/441,151 (36.5%) - checkpoint saved
#
# Batch 162/442: articles 161,000 - 162,000 (1,000 texts)
# Progress: 162,000/441,151 (36.7%) - checkpoint saved
#
# Batch 163/442: articles 162,000 - 163,000 (1,000 texts)
# Progress: 163,000/441,151 (36.9%) - checkpoint saved
#
# Batch 164/442: articles 163,000 - 164,000 (1,000 texts)
# Progress: 164,000/441,151 (37.2%) - checkpoint saved
#
# Batch 165/442: articles 164,000 - 165,000 (1,000 texts)
# Progress: 165,000/441,151 (37.4%) - checkpoint saved
#
# Batch 166/442: articles 165,000 - 166,000 (1,000 texts)
# Progress: 166,000/441,151 (37.6%) - checkpoint saved
#
# Batch 167/442: articles 166,000 - 167,000 (1,000 texts)
# Progress: 167,000/441,151 (37.9%) - checkpoint saved
#
# Batch 168/442: articles 167,000 - 168,000 (1,000 texts)
# Progress: 168,000/441,151 (38.1%) - checkpoint saved
#
# Batch 169/442: articles 168,000 - 169,000 (1,000 texts)
# Progress: 169,000/441,151 (38.3%) - checkpoint saved
#
# Batch 170/442: articles 169,000 - 170,000 (1,000 texts)
# Progress: 170,000/441,151 (38.5%) - checkpoint saved
#
# Batch 171/442: articles 170,000 - 171,000 (1,000 texts)
# Progress: 171,000/441,151 (38.8%) - checkpoint saved
#
# Batch 172/442: articles 171,000 - 172,000 (1,000 texts)
# Progress: 172,000/441,151 (39.0%) - checkpoint saved
#
# Batch 173/442: articles 172,000 - 173,000 (1,000 texts)
# Progress: 173,000/441,151 (39.2%) - checkpoint saved
#
# Batch 174/442: articles 173,000 - 174,000 (1,000 texts)
# Progress: 174,000/441,151 (39.4%) - checkpoint saved
#
# Batch 175/442: articles 174,000 - 175,000 (1,000 texts)
# Progress: 175,000/441,151 (39.7%) - checkpoint saved
#
# Batch 176/442: articles 175,000 - 176,000 (1,000 texts)
# Progress: 176,000/441,151 (39.9%) - checkpoint saved
#
# Batch 177/442: articles 176,000 - 177,000 (1,000 texts)
# Progress: 177,000/441,151 (40.1%) - checkpoint saved
#
# Batch 178/442: articles 177,000 - 178,000 (1,000 texts)
# Progress: 178,000/441,151 (40.3%) - checkpoint saved
#
# Batch 179/442: articles 178,000 - 179,000 (1,000 texts)
# Progress: 179,000/441,151 (40.6%) - checkpoint saved
#
# Batch 180/442: articles 179,000 - 180,000 (1,000 texts)
# Progress: 180,000/441,151 (40.8%) - checkpoint saved
#
# Batch 181/442: articles 180,000 - 181,000 (1,000 texts)
# Progress: 181,000/441,151 (41.0%) - checkpoint saved
#
# Batch 182/442: articles 181,000 - 182,000 (1,000 texts)
# Progress: 182,000/441,151 (41.3%) - checkpoint saved
#
# Batch 183/442: articles 182,000 - 183,000 (1,000 texts)
# Progress: 183,000/441,151 (41.5%) - checkpoint saved
#
# Batch 184/442: articles 183,000 - 184,000 (1,000 texts)
# Progress: 184,000/441,151 (41.7%) - checkpoint saved
#
# Batch 185/442: articles 184,000 - 185,000 (1,000 texts)
# Progress: 185,000/441,151 (41.9%) - checkpoint saved
#
# Batch 186/442: articles 185,000 - 186,000 (1,000 texts)
# Progress: 186,000/441,151 (42.2%) - checkpoint saved
#
# Batch 187/442: articles 186,000 - 187,000 (1,000 texts)
# Progress: 187,000/441,151 (42.4%) - checkpoint saved
#
# Batch 188/442: articles 187,000 - 188,000 (1,000 texts)
# Progress: 188,000/441,151 (42.6%) - checkpoint saved
#
# Batch 189/442: articles 188,000 - 189,000 (1,000 texts)
# Progress: 189,000/441,151 (42.8%) - checkpoint saved
#
# Batch 190/442: articles 189,000 - 190,000 (1,000 texts)
# Progress: 190,000/441,151 (43.1%) - checkpoint saved
#
# Batch 191/442: articles 190,000 - 191,000 (1,000 texts)
# Progress: 191,000/441,151 (43.3%) - checkpoint saved
#
# Batch 192/442: articles 191,000 - 192,000 (1,000 texts)
# Progress: 192,000/441,151 (43.5%) - checkpoint saved
#
# Batch 193/442: articles 192,000 - 193,000 (1,000 texts)
# Progress: 193,000/441,151 (43.7%) - checkpoint saved
#
# Batch 194/442: articles 193,000 - 194,000 (1,000 texts)
# Progress: 194,000/441,151 (44.0%) - checkpoint saved
#
# Batch 195/442: articles 194,000 - 195,000 (1,000 texts)
# Progress: 195,000/441,151 (44.2%) - checkpoint saved
#
# Batch 196/442: articles 195,000 - 196,000 (1,000 texts)
# Progress: 196,000/441,151 (44.4%) - checkpoint saved
#
# Batch 197/442: articles 196,000 - 197,000 (1,000 texts)
# Progress: 197,000/441,151 (44.7%) - checkpoint saved
#
# Batch 198/442: articles 197,000 - 198,000 (1,000 texts)
# Progress: 198,000/441,151 (44.9%) - checkpoint saved
#
# Batch 199/442: articles 198,000 - 199,000 (1,000 texts)
# Progress: 199,000/441,151 (45.1%) - checkpoint saved
#
# Batch 200/442: articles 199,000 - 200,000 (1,000 texts)
# Progress: 200,000/441,151 (45.3%) - checkpoint saved
#
# Batch 201/442: articles 200,000 - 201,000 (1,000 texts)
# Progress: 201,000/441,151 (45.6%) - checkpoint saved
#
# Batch 202/442: articles 201,000 - 202,000 (1,000 texts)
# Progress: 202,000/441,151 (45.8%) - checkpoint saved
#
# Batch 203/442: articles 202,000 - 203,000 (1,000 texts)
# Progress: 203,000/441,151 (46.0%) - checkpoint saved
#
# Batch 204/442: articles 203,000 - 204,000 (1,000 texts)
# Progress: 204,000/441,151 (46.2%) - checkpoint saved
#
# Batch 205/442: articles 204,000 - 205,000 (1,000 texts)
# Progress: 205,000/441,151 (46.5%) - checkpoint saved
#
# Batch 206/442: articles 205,000 - 206,000 (1,000 texts)
# Progress: 206,000/441,151 (46.7%) - checkpoint saved
#
# Batch 207/442: articles 206,000 - 207,000 (1,000 texts)
# Progress: 207,000/441,151 (46.9%) - checkpoint saved
#
# Batch 208/442: articles 207,000 - 208,000 (1,000 texts)
# Progress: 208,000/441,151 (47.1%) - checkpoint saved
#
# Batch 209/442: articles 208,000 - 209,000 (1,000 texts)
# Progress: 209,000/441,151 (47.4%) - checkpoint saved
#
# Batch 210/442: articles 209,000 - 210,000 (1,000 texts)
# Progress: 210,000/441,151 (47.6%) - checkpoint saved
#
# Batch 211/442: articles 210,000 - 211,000 (1,000 texts)
# Progress: 211,000/441,151 (47.8%) - checkpoint saved
#
# Batch 212/442: articles 211,000 - 212,000 (1,000 texts)
# Progress: 212,000/441,151 (48.1%) - checkpoint saved
#
# Batch 213/442: articles 212,000 - 213,000 (1,000 texts)
# Progress: 213,000/441,151 (48.3%) - checkpoint saved
#
# Batch 214/442: articles 213,000 - 214,000 (1,000 texts)
# Progress: 214,000/441,151 (48.5%) - checkpoint saved
#
# Batch 215/442: articles 214,000 - 215,000 (1,000 texts)
# Progress: 215,000/441,151 (48.7%) - checkpoint saved
#
# Batch 216/442: articles 215,000 - 216,000 (1,000 texts)
# Progress: 216,000/441,151 (49.0%) - checkpoint saved
#
# Batch 217/442: articles 216,000 - 217,000 (1,000 texts)
# Progress: 217,000/441,151 (49.2%) - checkpoint saved
#
# Batch 218/442: articles 217,000 - 218,000 (1,000 texts)
# Progress: 218,000/441,151 (49.4%) - checkpoint saved
#
# Batch 219/442: articles 218,000 - 219,000 (1,000 texts)
# Progress: 219,000/441,151 (49.6%) - checkpoint saved
#
# Batch 220/442: articles 219,000 - 220,000 (1,000 texts)
# Progress: 220,000/441,151 (49.9%) - checkpoint saved
#
# Batch 221/442: articles 220,000 - 221,000 (1,000 texts)
# Progress: 221,000/441,151 (50.1%) - checkpoint saved
#
# Batch 222/442: articles 221,000 - 222,000 (1,000 texts)
# Progress: 222,000/441,151 (50.3%) - checkpoint saved
#
# Batch 223/442: articles 222,000 - 223,000 (1,000 texts)
# Progress: 223,000/441,151 (50.5%) - checkpoint saved
#
# Batch 224/442: articles 223,000 - 224,000 (1,000 texts)
# Progress: 224,000/441,151 (50.8%) - checkpoint saved
#
# Batch 225/442: articles 224,000 - 225,000 (1,000 texts)
# Progress: 225,000/441,151 (51.0%) - checkpoint saved
#
# Batch 226/442: articles 225,000 - 226,000 (1,000 texts)
# Progress: 226,000/441,151 (51.2%) - checkpoint saved
#
# Batch 227/442: articles 226,000 - 227,000 (1,000 texts)
# Progress: 227,000/441,151 (51.5%) - checkpoint saved
#
# Batch 228/442: articles 227,000 - 228,000 (1,000 texts)
# Progress: 228,000/441,151 (51.7%) - checkpoint saved
#
# Batch 229/442: articles 228,000 - 229,000 (1,000 texts)
# Progress: 229,000/441,151 (51.9%) - checkpoint saved
#
# Batch 230/442: articles 229,000 - 230,000 (1,000 texts)
# Progress: 230,000/441,151 (52.1%) - checkpoint saved
#
# Batch 231/442: articles 230,000 - 231,000 (1,000 texts)
# Progress: 231,000/441,151 (52.4%) - checkpoint saved
#
# Batch 232/442: articles 231,000 - 232,000 (1,000 texts)
# Progress: 232,000/441,151 (52.6%) - checkpoint saved
#
# Batch 233/442: articles 232,000 - 233,000 (1,000 texts)
# Progress: 233,000/441,151 (52.8%) - checkpoint saved
#
# Batch 234/442: articles 233,000 - 234,000 (1,000 texts)
# Progress: 234,000/441,151 (53.0%) - checkpoint saved
#
# Batch 235/442: articles 234,000 - 235,000 (1,000 texts)
# Progress: 235,000/441,151 (53.3%) - checkpoint saved
#
# Batch 236/442: articles 235,000 - 236,000 (1,000 texts)
# Progress: 236,000/441,151 (53.5%) - checkpoint saved
#
# Batch 237/442: articles 236,000 - 237,000 (1,000 texts)
# Progress: 237,000/441,151 (53.7%) - checkpoint saved
#
# Batch 238/442: articles 237,000 - 238,000 (1,000 texts)
# Progress: 238,000/441,151 (53.9%) - checkpoint saved
#
# Batch 239/442: articles 238,000 - 239,000 (1,000 texts)
# Progress: 239,000/441,151 (54.2%) - checkpoint saved
#
# Batch 240/442: articles 239,000 - 240,000 (1,000 texts)
# Progress: 240,000/441,151 (54.4%) - checkpoint saved
#
# Batch 241/442: articles 240,000 - 241,000 (1,000 texts)
# Progress: 241,000/441,151 (54.6%) - checkpoint saved
#
# Batch 242/442: articles 241,000 - 242,000 (1,000 texts)
# Progress: 242,000/441,151 (54.9%) - checkpoint saved
#
# Batch 243/442: articles 242,000 - 243,000 (1,000 texts)
# Progress: 243,000/441,151 (55.1%) - checkpoint saved
#
# Batch 244/442: articles 243,000 - 244,000 (1,000 texts)
# Progress: 244,000/441,151 (55.3%) - checkpoint saved
#
# Batch 245/442: articles 244,000 - 245,000 (1,000 texts)
# Progress: 245,000/441,151 (55.5%) - checkpoint saved
#
# Batch 246/442: articles 245,000 - 246,000 (1,000 texts)
# Progress: 246,000/441,151 (55.8%) - checkpoint saved
#
# Batch 247/442: articles 246,000 - 247,000 (1,000 texts)
# Progress: 247,000/441,151 (56.0%) - checkpoint saved
#
# Batch 248/442: articles 247,000 - 248,000 (1,000 texts)
# Progress: 248,000/441,151 (56.2%) - checkpoint saved
#
# Batch 249/442: articles 248,000 - 249,000 (1,000 texts)
# Progress: 249,000/441,151 (56.4%) - checkpoint saved
#
# Batch 250/442: articles 249,000 - 250,000 (1,000 texts)
# Progress: 250,000/441,151 (56.7%) - checkpoint saved
#
# Batch 251/442: articles 250,000 - 251,000 (1,000 texts)
# Progress: 251,000/441,151 (56.9%) - checkpoint saved
#
# Batch 252/442: articles 251,000 - 252,000 (1,000 texts)
# Progress: 252,000/441,151 (57.1%) - checkpoint saved
#
# Batch 253/442: articles 252,000 - 253,000 (1,000 texts)
# Progress: 253,000/441,151 (57.3%) - checkpoint saved
#
# Batch 254/442: articles 253,000 - 254,000 (1,000 texts)
# Progress: 254,000/441,151 (57.6%) - checkpoint saved
#
# Batch 255/442: articles 254,000 - 255,000 (1,000 texts)
# Progress: 255,000/441,151 (57.8%) - checkpoint saved
#
# Batch 256/442: articles 255,000 - 256,000 (1,000 texts)
# Progress: 256,000/441,151 (58.0%) - checkpoint saved
#
# Batch 257/442: articles 256,000 - 257,000 (1,000 texts)
# Progress: 257,000/441,151 (58.3%) - checkpoint saved
#
# Batch 258/442: articles 257,000 - 258,000 (1,000 texts)
# Progress: 258,000/441,151 (58.5%) - checkpoint saved
#
# Batch 259/442: articles 258,000 - 259,000 (1,000 texts)
# Progress: 259,000/441,151 (58.7%) - checkpoint saved
#
# Batch 260/442: articles 259,000 - 260,000 (1,000 texts)
# Progress: 260,000/441,151 (58.9%) - checkpoint saved
#
# Batch 261/442: articles 260,000 - 261,000 (1,000 texts)
# Progress: 261,000/441,151 (59.2%) - checkpoint saved
#
# Batch 262/442: articles 261,000 - 262,000 (1,000 texts)
# Progress: 262,000/441,151 (59.4%) - checkpoint saved
#
# Batch 263/442: articles 262,000 - 263,000 (1,000 texts)
# Progress: 263,000/441,151 (59.6%) - checkpoint saved
#
# Batch 264/442: articles 263,000 - 264,000 (1,000 texts)
# Progress: 264,000/441,151 (59.8%) - checkpoint saved
#
# Batch 265/442: articles 264,000 - 265,000 (1,000 texts)
# Progress: 265,000/441,151 (60.1%) - checkpoint saved
#
# Batch 266/442: articles 265,000 - 266,000 (1,000 texts)
# Progress: 266,000/441,151 (60.3%) - checkpoint saved
#
# Batch 267/442: articles 266,000 - 267,000 (1,000 texts)
# Progress: 267,000/441,151 (60.5%) - checkpoint saved
#
# Batch 268/442: articles 267,000 - 268,000 (1,000 texts)
# Progress: 268,000/441,151 (60.8%) - checkpoint saved
#
# Batch 269/442: articles 268,000 - 269,000 (1,000 texts)
# Progress: 269,000/441,151 (61.0%) - checkpoint saved
#
# Batch 270/442: articles 269,000 - 270,000 (1,000 texts)
# Progress: 270,000/441,151 (61.2%) - checkpoint saved
#
# Batch 271/442: articles 270,000 - 271,000 (1,000 texts)
# Progress: 271,000/441,151 (61.4%) - checkpoint saved
#
# Batch 272/442: articles 271,000 - 272,000 (1,000 texts)
# Progress: 272,000/441,151 (61.7%) - checkpoint saved
#
# Batch 273/442: articles 272,000 - 273,000 (1,000 texts)
# Progress: 273,000/441,151 (61.9%) - checkpoint saved
#
# Batch 274/442: articles 273,000 - 274,000 (1,000 texts)
# Progress: 274,000/441,151 (62.1%) - checkpoint saved
#
# Batch 275/442: articles 274,000 - 275,000 (1,000 texts)
# Progress: 275,000/441,151 (62.3%) - checkpoint saved
#
# Batch 276/442: articles 275,000 - 276,000 (1,000 texts)
# Progress: 276,000/441,151 (62.6%) - checkpoint saved
#
# Batch 277/442: articles 276,000 - 277,000 (1,000 texts)
# Progress: 277,000/441,151 (62.8%) - checkpoint saved
#
# Batch 278/442: articles 277,000 - 278,000 (1,000 texts)
# Progress: 278,000/441,151 (63.0%) - checkpoint saved
#
# Batch 279/442: articles 278,000 - 279,000 (1,000 texts)
# Progress: 279,000/441,151 (63.2%) - checkpoint saved
#
# Batch 280/442: articles 279,000 - 280,000 (1,000 texts)
# Progress: 280,000/441,151 (63.5%) - checkpoint saved
#
# Batch 281/442: articles 280,000 - 281,000 (1,000 texts)
# Progress: 281,000/441,151 (63.7%) - checkpoint saved
#
# Batch 282/442: articles 281,000 - 282,000 (1,000 texts)
# Progress: 282,000/441,151 (63.9%) - checkpoint saved
#
# Batch 283/442: articles 282,000 - 283,000 (1,000 texts)
# Progress: 283,000/441,151 (64.2%) - checkpoint saved
#
# Batch 284/442: articles 283,000 - 284,000 (1,000 texts)
# Progress: 284,000/441,151 (64.4%) - checkpoint saved
#
# Batch 285/442: articles 284,000 - 285,000 (1,000 texts)
# Progress: 285,000/441,151 (64.6%) - checkpoint saved
#
# Batch 286/442: articles 285,000 - 286,000 (1,000 texts)
# Progress: 286,000/441,151 (64.8%) - checkpoint saved
#
# Batch 287/442: articles 286,000 - 287,000 (1,000 texts)
# Progress: 287,000/441,151 (65.1%) - checkpoint saved
#
# Batch 288/442: articles 287,000 - 288,000 (1,000 texts)
# Progress: 288,000/441,151 (65.3%) - checkpoint saved
#
# Batch 289/442: articles 288,000 - 289,000 (1,000 texts)
# Progress: 289,000/441,151 (65.5%) - checkpoint saved
#
# Batch 290/442: articles 289,000 - 290,000 (1,000 texts)
# Progress: 290,000/441,151 (65.7%) - checkpoint saved
#
# Batch 291/442: articles 290,000 - 291,000 (1,000 texts)
# Progress: 291,000/441,151 (66.0%) - checkpoint saved
#
# Batch 292/442: articles 291,000 - 292,000 (1,000 texts)
# Progress: 292,000/441,151 (66.2%) - checkpoint saved
#
# Batch 293/442: articles 292,000 - 293,000 (1,000 texts)
# Progress: 293,000/441,151 (66.4%) - checkpoint saved
#
# Batch 294/442: articles 293,000 - 294,000 (1,000 texts)
# Progress: 294,000/441,151 (66.6%) - checkpoint saved
#
# Batch 295/442: articles 294,000 - 295,000 (1,000 texts)
# Progress: 295,000/441,151 (66.9%) - checkpoint saved
#
# Batch 296/442: articles 295,000 - 296,000 (1,000 texts)
# Progress: 296,000/441,151 (67.1%) - checkpoint saved
#
# Batch 297/442: articles 296,000 - 297,000 (1,000 texts)
# Progress: 297,000/441,151 (67.3%) - checkpoint saved
#
# Batch 298/442: articles 297,000 - 298,000 (1,000 texts)
# Progress: 298,000/441,151 (67.6%) - checkpoint saved
#
# Batch 299/442: articles 298,000 - 299,000 (1,000 texts)
# Progress: 299,000/441,151 (67.8%) - checkpoint saved
#
# Batch 300/442: articles 299,000 - 300,000 (1,000 texts)
# Progress: 300,000/441,151 (68.0%) - checkpoint saved
#
# Batch 301/442: articles 300,000 - 301,000 (1,000 texts)
# Progress: 301,000/441,151 (68.2%) - checkpoint saved
#
# Batch 302/442: articles 301,000 - 302,000 (1,000 texts)
# Progress: 302,000/441,151 (68.5%) - checkpoint saved
#
# Batch 303/442: articles 302,000 - 303,000 (1,000 texts)
# Progress: 303,000/441,151 (68.7%) - checkpoint saved
#
# Batch 304/442: articles 303,000 - 304,000 (1,000 texts)
# Progress: 304,000/441,151 (68.9%) - checkpoint saved
#
# Batch 305/442: articles 304,000 - 305,000 (1,000 texts)
# Progress: 305,000/441,151 (69.1%) - checkpoint saved
#
# Batch 306/442: articles 305,000 - 306,000 (1,000 texts)
# Progress: 306,000/441,151 (69.4%) - checkpoint saved
#
# Batch 307/442: articles 306,000 - 307,000 (1,000 texts)
# Progress: 307,000/441,151 (69.6%) - checkpoint saved
#
# Batch 308/442: articles 307,000 - 308,000 (1,000 texts)
# Progress: 308,000/441,151 (69.8%) - checkpoint saved
#
# Batch 309/442: articles 308,000 - 309,000 (1,000 texts)
# Progress: 309,000/441,151 (70.0%) - checkpoint saved
#
# Batch 310/442: articles 309,000 - 310,000 (1,000 texts)
# Progress: 310,000/441,151 (70.3%) - checkpoint saved
#
# Batch 311/442: articles 310,000 - 311,000 (1,000 texts)
# Progress: 311,000/441,151 (70.5%) - checkpoint saved
#
# Batch 312/442: articles 311,000 - 312,000 (1,000 texts)
# Progress: 312,000/441,151 (70.7%) - checkpoint saved
#
# Batch 313/442: articles 312,000 - 313,000 (1,000 texts)
# Progress: 313,000/441,151 (71.0%) - checkpoint saved
#
# Batch 314/442: articles 313,000 - 314,000 (1,000 texts)
# Progress: 314,000/441,151 (71.2%) - checkpoint saved
#
# Batch 315/442: articles 314,000 - 315,000 (1,000 texts)
# Progress: 315,000/441,151 (71.4%) - checkpoint saved
#
# Batch 316/442: articles 315,000 - 316,000 (1,000 texts)
# Progress: 316,000/441,151 (71.6%) - checkpoint saved
#
# Batch 317/442: articles 316,000 - 317,000 (1,000 texts)
# Progress: 317,000/441,151 (71.9%) - checkpoint saved
#
# Batch 318/442: articles 317,000 - 318,000 (1,000 texts)
# Progress: 318,000/441,151 (72.1%) - checkpoint saved
#
# Batch 319/442: articles 318,000 - 319,000 (1,000 texts)
# Progress: 319,000/441,151 (72.3%) - checkpoint saved
#
# Batch 320/442: articles 319,000 - 320,000 (1,000 texts)
# Progress: 320,000/441,151 (72.5%) - checkpoint saved
#
# Batch 321/442: articles 320,000 - 321,000 (1,000 texts)
# Progress: 321,000/441,151 (72.8%) - checkpoint saved
#
# Batch 322/442: articles 321,000 - 322,000 (1,000 texts)
# Progress: 322,000/441,151 (73.0%) - checkpoint saved
#
# Batch 323/442: articles 322,000 - 323,000 (1,000 texts)
# Progress: 323,000/441,151 (73.2%) - checkpoint saved
#
# Batch 324/442: articles 323,000 - 324,000 (1,000 texts)
# Progress: 324,000/441,151 (73.4%) - checkpoint saved
#
# Batch 325/442: articles 324,000 - 325,000 (1,000 texts)
# Progress: 325,000/441,151 (73.7%) - checkpoint saved
#
# Batch 326/442: articles 325,000 - 326,000 (1,000 texts)
# Progress: 326,000/441,151 (73.9%) - checkpoint saved
#
# Batch 327/442: articles 326,000 - 327,000 (1,000 texts)
# Progress: 327,000/441,151 (74.1%) - checkpoint saved
#
# Batch 328/442: articles 327,000 - 328,000 (1,000 texts)
# Progress: 328,000/441,151 (74.4%) - checkpoint saved
#
# Batch 329/442: articles 328,000 - 329,000 (1,000 texts)
# Progress: 329,000/441,151 (74.6%) - checkpoint saved
#
# Batch 330/442: articles 329,000 - 330,000 (1,000 texts)
# Progress: 330,000/441,151 (74.8%) - checkpoint saved
#
# Batch 331/442: articles 330,000 - 331,000 (1,000 texts)
# Progress: 331,000/441,151 (75.0%) - checkpoint saved
#
# Batch 332/442: articles 331,000 - 332,000 (1,000 texts)
# Progress: 332,000/441,151 (75.3%) - checkpoint saved
#
# Batch 333/442: articles 332,000 - 333,000 (1,000 texts)
# Progress: 333,000/441,151 (75.5%) - checkpoint saved
#
# Batch 334/442: articles 333,000 - 334,000 (1,000 texts)
# Progress: 334,000/441,151 (75.7%) - checkpoint saved
#
# Batch 335/442: articles 334,000 - 335,000 (1,000 texts)
# Progress: 335,000/441,151 (75.9%) - checkpoint saved
#
# Batch 336/442: articles 335,000 - 336,000 (1,000 texts)
# Progress: 336,000/441,151 (76.2%) - checkpoint saved
#
# Batch 337/442: articles 336,000 - 337,000 (1,000 texts)
# Progress: 337,000/441,151 (76.4%) - checkpoint saved
#
# Batch 338/442: articles 337,000 - 338,000 (1,000 texts)
# Progress: 338,000/441,151 (76.6%) - checkpoint saved
#
# Batch 339/442: articles 338,000 - 339,000 (1,000 texts)
# Progress: 339,000/441,151 (76.8%) - checkpoint saved
#
# Batch 340/442: articles 339,000 - 340,000 (1,000 texts)
# Progress: 340,000/441,151 (77.1%) - checkpoint saved
#
# Batch 341/442: articles 340,000 - 341,000 (1,000 texts)
# Progress: 341,000/441,151 (77.3%) - checkpoint saved
#
# Batch 342/442: articles 341,000 - 342,000 (1,000 texts)
# Progress: 342,000/441,151 (77.5%) - checkpoint saved
#
# Batch 343/442: articles 342,000 - 343,000 (1,000 texts)
# Progress: 343,000/441,151 (77.8%) - checkpoint saved
#
# Batch 344/442: articles 343,000 - 344,000 (1,000 texts)
# Progress: 344,000/441,151 (78.0%) - checkpoint saved
#
# Batch 345/442: articles 344,000 - 345,000 (1,000 texts)
# Progress: 345,000/441,151 (78.2%) - checkpoint saved
#
# Batch 346/442: articles 345,000 - 346,000 (1,000 texts)
# Progress: 346,000/441,151 (78.4%) - checkpoint saved
#
# Batch 347/442: articles 346,000 - 347,000 (1,000 texts)
# Progress: 347,000/441,151 (78.7%) - checkpoint saved
#
# Batch 348/442: articles 347,000 - 348,000 (1,000 texts)
# Progress: 348,000/441,151 (78.9%) - checkpoint saved
#
# Batch 349/442: articles 348,000 - 349,000 (1,000 texts)
# Progress: 349,000/441,151 (79.1%) - checkpoint saved
#
# Batch 350/442: articles 349,000 - 350,000 (1,000 texts)
# Progress: 350,000/441,151 (79.3%) - checkpoint saved
#
# Batch 351/442: articles 350,000 - 351,000 (1,000 texts)
# Progress: 351,000/441,151 (79.6%) - checkpoint saved
#
# Batch 352/442: articles 351,000 - 352,000 (1,000 texts)
# Progress: 352,000/441,151 (79.8%) - checkpoint saved
#
# Batch 353/442: articles 352,000 - 353,000 (1,000 texts)
# Progress: 353,000/441,151 (80.0%) - checkpoint saved
#
# Batch 354/442: articles 353,000 - 354,000 (1,000 texts)
# Progress: 354,000/441,151 (80.2%) - checkpoint saved
#
# Batch 355/442: articles 354,000 - 355,000 (1,000 texts)
# Progress: 355,000/441,151 (80.5%) - checkpoint saved
#
# Batch 356/442: articles 355,000 - 356,000 (1,000 texts)
# Progress: 356,000/441,151 (80.7%) - checkpoint saved
#
# Batch 357/442: articles 356,000 - 357,000 (1,000 texts)
# Progress: 357,000/441,151 (80.9%) - checkpoint saved
#
# Batch 358/442: articles 357,000 - 358,000 (1,000 texts)
# Progress: 358,000/441,151 (81.2%) - checkpoint saved
#
# Batch 359/442: articles 358,000 - 359,000 (1,000 texts)
# Progress: 359,000/441,151 (81.4%) - checkpoint saved
#
# Batch 360/442: articles 359,000 - 360,000 (1,000 texts)
# Progress: 360,000/441,151 (81.6%) - checkpoint saved
#
# Batch 361/442: articles 360,000 - 361,000 (1,000 texts)
# Progress: 361,000/441,151 (81.8%) - checkpoint saved
#
# Batch 362/442: articles 361,000 - 362,000 (1,000 texts)
# Progress: 362,000/441,151 (82.1%) - checkpoint saved
#
# Batch 363/442: articles 362,000 - 363,000 (1,000 texts)
# Progress: 363,000/441,151 (82.3%) - checkpoint saved
#
# Batch 364/442: articles 363,000 - 364,000 (1,000 texts)
# Progress: 364,000/441,151 (82.5%) - checkpoint saved
#
# Batch 365/442: articles 364,000 - 365,000 (1,000 texts)
# Progress: 365,000/441,151 (82.7%) - checkpoint saved
#
# Batch 366/442: articles 365,000 - 366,000 (1,000 texts)
# Progress: 366,000/441,151 (83.0%) - checkpoint saved
#
# Batch 367/442: articles 366,000 - 367,000 (1,000 texts)
# Progress: 367,000/441,151 (83.2%) - checkpoint saved
#
# Batch 368/442: articles 367,000 - 368,000 (1,000 texts)
# Progress: 368,000/441,151 (83.4%) - checkpoint saved
#
# Batch 369/442: articles 368,000 - 369,000 (1,000 texts)
# Progress: 369,000/441,151 (83.6%) - checkpoint saved
#
# Batch 370/442: articles 369,000 - 370,000 (1,000 texts)
# Progress: 370,000/441,151 (83.9%) - checkpoint saved
#
# Batch 371/442: articles 370,000 - 371,000 (1,000 texts)
# Progress: 371,000/441,151 (84.1%) - checkpoint saved
#
# Batch 372/442: articles 371,000 - 372,000 (1,000 texts)
# Progress: 372,000/441,151 (84.3%) - checkpoint saved
#
# Batch 373/442: articles 372,000 - 373,000 (1,000 texts)
# Progress: 373,000/441,151 (84.6%) - checkpoint saved
#
# Batch 374/442: articles 373,000 - 374,000 (1,000 texts)
# Progress: 374,000/441,151 (84.8%) - checkpoint saved
#
# Batch 375/442: articles 374,000 - 375,000 (1,000 texts)
# Progress: 375,000/441,151 (85.0%) - checkpoint saved
#
# Batch 376/442: articles 375,000 - 376,000 (1,000 texts)
# Progress: 376,000/441,151 (85.2%) - checkpoint saved
#
# Batch 377/442: articles 376,000 - 377,000 (1,000 texts)
# Progress: 377,000/441,151 (85.5%) - checkpoint saved
#
# Batch 378/442: articles 377,000 - 378,000 (1,000 texts)
# Progress: 378,000/441,151 (85.7%) - checkpoint saved
#
# Batch 379/442: articles 378,000 - 379,000 (1,000 texts)
# Progress: 379,000/441,151 (85.9%) - checkpoint saved
#
# Batch 380/442: articles 379,000 - 380,000 (1,000 texts)
# Progress: 380,000/441,151 (86.1%) - checkpoint saved
#
# Batch 381/442: articles 380,000 - 381,000 (1,000 texts)
# Progress: 381,000/441,151 (86.4%) - checkpoint saved
#
# Batch 382/442: articles 381,000 - 382,000 (1,000 texts)
# Progress: 382,000/441,151 (86.6%) - checkpoint saved
#
# Batch 383/442: articles 382,000 - 383,000 (1,000 texts)
# Progress: 383,000/441,151 (86.8%) - checkpoint saved
#
# Batch 384/442: articles 383,000 - 384,000 (1,000 texts)
# Progress: 384,000/441,151 (87.0%) - checkpoint saved
#
# Batch 385/442: articles 384,000 - 385,000 (1,000 texts)
# Progress: 385,000/441,151 (87.3%) - checkpoint saved
#
# Batch 386/442: articles 385,000 - 386,000 (1,000 texts)
# Progress: 386,000/441,151 (87.5%) - checkpoint saved
#
# Batch 387/442: articles 386,000 - 387,000 (1,000 texts)
# Progress: 387,000/441,151 (87.7%) - checkpoint saved
#
# Batch 388/442: articles 387,000 - 388,000 (1,000 texts)
# Progress: 388,000/441,151 (88.0%) - checkpoint saved
#
# Batch 389/442: articles 388,000 - 389,000 (1,000 texts)
# Progress: 389,000/441,151 (88.2%) - checkpoint saved
#
# Batch 390/442: articles 389,000 - 390,000 (1,000 texts)
# Progress: 390,000/441,151 (88.4%) - checkpoint saved
#
# Batch 391/442: articles 390,000 - 391,000 (1,000 texts)
# Progress: 391,000/441,151 (88.6%) - checkpoint saved
#
# Batch 392/442: articles 391,000 - 392,000 (1,000 texts)
# Progress: 392,000/441,151 (88.9%) - checkpoint saved
#
# Batch 393/442: articles 392,000 - 393,000 (1,000 texts)
# Progress: 393,000/441,151 (89.1%) - checkpoint saved
#
# Batch 394/442: articles 393,000 - 394,000 (1,000 texts)
# Progress: 394,000/441,151 (89.3%) - checkpoint saved
#
# Batch 395/442: articles 394,000 - 395,000 (1,000 texts)
# Progress: 395,000/441,151 (89.5%) - checkpoint saved
#
# Batch 396/442: articles 395,000 - 396,000 (1,000 texts)
# Progress: 396,000/441,151 (89.8%) - checkpoint saved
#
# Batch 397/442: articles 396,000 - 397,000 (1,000 texts)
# Progress: 397,000/441,151 (90.0%) - checkpoint saved
#
# Batch 398/442: articles 397,000 - 398,000 (1,000 texts)
# Progress: 398,000/441,151 (90.2%) - checkpoint saved
#
# Batch 399/442: articles 398,000 - 399,000 (1,000 texts)
# Progress: 399,000/441,151 (90.4%) - checkpoint saved
#
# Batch 400/442: articles 399,000 - 400,000 (1,000 texts)
# Progress: 400,000/441,151 (90.7%) - checkpoint saved
#
# Batch 401/442: articles 400,000 - 401,000 (1,000 texts)
# Progress: 401,000/441,151 (90.9%) - checkpoint saved
#
# Batch 402/442: articles 401,000 - 402,000 (1,000 texts)
# Progress: 402,000/441,151 (91.1%) - checkpoint saved
#
# Batch 403/442: articles 402,000 - 403,000 (1,000 texts)
# Progress: 403,000/441,151 (91.4%) - checkpoint saved
#
# Batch 404/442: articles 403,000 - 404,000 (1,000 texts)
# Progress: 404,000/441,151 (91.6%) - checkpoint saved
#
# Batch 405/442: articles 404,000 - 405,000 (1,000 texts)
# Progress: 405,000/441,151 (91.8%) - checkpoint saved
#
# Batch 406/442: articles 405,000 - 406,000 (1,000 texts)
# Progress: 406,000/441,151 (92.0%) - checkpoint saved
#
# Batch 407/442: articles 406,000 - 407,000 (1,000 texts)
# Progress: 407,000/441,151 (92.3%) - checkpoint saved
#
# Batch 408/442: articles 407,000 - 408,000 (1,000 texts)
# Progress: 408,000/441,151 (92.5%) - checkpoint saved
#
# Batch 409/442: articles 408,000 - 409,000 (1,000 texts)
# Progress: 409,000/441,151 (92.7%) - checkpoint saved
#
# Batch 410/442: articles 409,000 - 410,000 (1,000 texts)
# Progress: 410,000/441,151 (92.9%) - checkpoint saved
#
# Batch 411/442: articles 410,000 - 411,000 (1,000 texts)
# Progress: 411,000/441,151 (93.2%) - checkpoint saved
#
# Batch 412/442: articles 411,000 - 412,000 (1,000 texts)
# Progress: 412,000/441,151 (93.4%) - checkpoint saved
#
# Batch 413/442: articles 412,000 - 413,000 (1,000 texts)
# Progress: 413,000/441,151 (93.6%) - checkpoint saved
#
# Batch 414/442: articles 413,000 - 414,000 (1,000 texts)
# Progress: 414,000/441,151 (93.8%) - checkpoint saved
#
# Batch 415/442: articles 414,000 - 415,000 (1,000 texts)
# Progress: 415,000/441,151 (94.1%) - checkpoint saved
#
# Batch 416/442: articles 415,000 - 416,000 (1,000 texts)
# Progress: 416,000/441,151 (94.3%) - checkpoint saved
#
# Batch 417/442: articles 416,000 - 417,000 (1,000 texts)
# Progress: 417,000/441,151 (94.5%) - checkpoint saved
#
# Batch 418/442: articles 417,000 - 418,000 (1,000 texts)
# Progress: 418,000/441,151 (94.8%) - checkpoint saved
#
# Batch 419/442: articles 418,000 - 419,000 (1,000 texts)
# Progress: 419,000/441,151 (95.0%) - checkpoint saved
#
# Batch 420/442: articles 419,000 - 420,000 (1,000 texts)
# Progress: 420,000/441,151 (95.2%) - checkpoint saved
#
# Batch 421/442: articles 420,000 - 421,000 (1,000 texts)
# Progress: 421,000/441,151 (95.4%) - checkpoint saved
#
# Batch 422/442: articles 421,000 - 422,000 (1,000 texts)
# Progress: 422,000/441,151 (95.7%) - checkpoint saved
#
# Batch 423/442: articles 422,000 - 423,000 (1,000 texts)
# Progress: 423,000/441,151 (95.9%) - checkpoint saved
#
# Batch 424/442: articles 423,000 - 424,000 (1,000 texts)
# Progress: 424,000/441,151 (96.1%) - checkpoint saved
#
# Batch 425/442: articles 424,000 - 425,000 (1,000 texts)
# Progress: 425,000/441,151 (96.3%) - checkpoint saved
#
# Batch 426/442: articles 425,000 - 426,000 (1,000 texts)
# Progress: 426,000/441,151 (96.6%) - checkpoint saved
#
# Batch 427/442: articles 426,000 - 427,000 (1,000 texts)
# Progress: 427,000/441,151 (96.8%) - checkpoint saved
#
# Batch 428/442: articles 427,000 - 428,000 (1,000 texts)
# Progress: 428,000/441,151 (97.0%) - checkpoint saved
#
# Batch 429/442: articles 428,000 - 429,000 (1,000 texts)
# Progress: 429,000/441,151 (97.2%) - checkpoint saved
#
# Batch 430/442: articles 429,000 - 430,000 (1,000 texts)
# Progress: 430,000/441,151 (97.5%) - checkpoint saved
#
# Batch 431/442: articles 430,000 - 431,000 (1,000 texts)
# Progress: 431,000/441,151 (97.7%) - checkpoint saved
#
# Batch 432/442: articles 431,000 - 432,000 (1,000 texts)
# Progress: 432,000/441,151 (97.9%) - checkpoint saved
#
# Batch 433/442: articles 432,000 - 433,000 (1,000 texts)
# Progress: 433,000/441,151 (98.2%) - checkpoint saved
#
# Batch 434/442: articles 433,000 - 434,000 (1,000 texts)
# Progress: 434,000/441,151 (98.4%) - checkpoint saved
#
# Batch 435/442: articles 434,000 - 435,000 (1,000 texts)
# Progress: 435,000/441,151 (98.6%) - checkpoint saved
#
# Batch 436/442: articles 435,000 - 436,000 (1,000 texts)
# Progress: 436,000/441,151 (98.8%) - checkpoint saved
#
# Batch 437/442: articles 436,000 - 437,000 (1,000 texts)
# Progress: 437,000/441,151 (99.1%) - checkpoint saved
#
# Batch 438/442: articles 437,000 - 438,000 (1,000 texts)
# Progress: 438,000/441,151 (99.3%) - checkpoint saved
#
# Batch 439/442: articles 438,000 - 439,000 (1,000 texts)
# Progress: 439,000/441,151 (99.5%) - checkpoint saved
#
# Batch 440/442: articles 439,000 - 440,000 (1,000 texts)
# Progress: 440,000/441,151 (99.7%) - checkpoint saved
#
# Batch 441/442: articles 440,000 - 441,000 (1,000 texts)
# Progress: 441,000/441,151 (100.0%) - checkpoint saved
#
# Batch 442/442: articles 441,000 - 441,151 (151 texts)
# Progress: 441,151/441,151 (100.0%) - checkpoint saved
# ------------------------------------------------------------
# Done! Total embeddings: 1,748,149

# %%
# Verify final output
final_df = pd.read_parquet(EMBEDDINGS_PATH)
print(f"Final embeddings: {len(final_df):,} rows")
print(f"File size: {final_df.memory_usage(deep=True).sum() / 1e9:.2f} GB")
final_df.head()
